# %% [markdown]
# ## Overview
#
# The EMISOpen consultation writeback is essentially a combination of several HL7 v2 Events.
#
# ### ADT_A04 - Register a Patient (patient encounter)
#
# | HL7 v2.4 Segment                                                     | HL7 FHIR Resource                                                                                                    | EMISOpen                                        |
# |----------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------|-------------------------------------------------|
# | [PID](https://hl7-definition.caristix.com/v2/HL7v2.4/Segments/PID)   | [Patient.identifier](https://virtually-healthcare.github.io/R4/StructureDefinition-Patient.html)                     | RegistrationType (extends IdentType)            |
# | [PV1](https://hl7-definition.caristix.com/v2/HL7v2.4/Segments/PV1})  | [Encounter](https://virtually-healthcare.github.io/R4/StructureDefinition-Encounter.html)                            | ConsultationType                                |
# | - [OBX](https://hl7-definition.caristix.com/v2/HL7v2.4/Segments/OBX) | [Observation](https://virtually-healthcare.github.io/R4/StructureDefinition-Observation.html)                        | EventType (both coded and uncoded)              |
# | OBX (type = ED)                                                      | [DocumentReference](https://virtually-healthcare.github.io/R4/StructureDefinition-DocumentReference.html) and Binary | Attachment                                      |
# | OBX (dependent on code)                                              | [Task](https://virtually-healthcare.github.io/R4/StructureDefinition-Task.html)                                      | DiaryType                                       |
# | OBX (dependent on code)                                              | [Immunization](https://virtually-healthcare.github.io/R4/StructureDefinition-Immunization.html)                      | EventType                                       |
# | - [AL1](https://hl7-definition.caristix.com/v2/HL7v2.4/Segments/AL1) | [AllergyIntolerance](https://virtually-healthcare.github.io/R4/StructureDefinition-AllergyIntolerance.html)                                                                                              | AllergyType                                     |
# | - [DG1](https://hl7-definition.caristix.com/v2/HL7v2.4/Segments/DG1) | [Condition](https://virtually-healthcare.github.io/R4/StructureDefinition-Condition.html)                            | EventType (with problem elements)               |
# | - [PR1](https://hl7-definition.caristix.com/v2/HL7v2.4/Segments/PR1) | [Procedure](https://virtually-healthcare.github.io/R4/StructureDefinition-Procedure.html)                            | EventType (can be inferred from SNOMED CT code) |
#
# ### RDE_O11 - Pharmacy/treatment encoded order
#
# | HL7 v2.4 Segment                                                    | HL7 FHIR Resource                                                                                         | EMISOpen                             |
# |---------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------|--------------------------------------|
# | [PID](https://hl7-definition.caristix.com/v2/HL7v2.4/Segments/PID)  | [Patient.identifier](https://virtually-healthcare.github.io/R4/StructureDefinition-Patient.html)          | RegistrationType (extends IdentType) |
# | [PV1](https://hl7-definition.caristix.com/v2/HL7v2.4/Segments/PV1}) | [Encounter](https://virtually-healthcare.github.io/R4/StructureDefinition-Encounter.html)                 | ConsultationType                     |
# | [RXE](https://hl7-definition.caristix.com/v2/HL7v2.4/Segments/RXE)  | [MedicationRequest](https://virtually-healthcare.github.io/R4/StructureDefinition-MedicationRequest.html) | MedicationType                       |
#
#
#
# ### Miscellaneous HL7 v2 Segments
#
# | HL7 v2.4 Segment                                                   | HL7 FHIR Resource                                                                                       | EMISOpen          |
# |--------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------|-------------------|
# | [ORC](https://hl7-definition.caristix.com/v2/HL7v2.4/Segments/ORC) | [ServiceRequest](https://virtually-healthcare.github.io/R4/StructureDefinition-ServiceRequest.html)     | ReferralType      |
# | [OBR](https://hl7-definition.caristix.com/v2/HL7v2.4/Segments/ORC) | [DiagnosticReport](https://virtually-healthcare.github.io/R4/StructureDefinition-DiagnosticReport.html) | InvestigationType |
#
# This is not a 100% accurate map, but we can see HL7 v2, FHIR and EMIS are related. Similar maps can be created to other GP systems, and they are similar. One of the main reasons for this is UK GP systems were based on early HL7, so they also share similar models with many secondary care systems and laboratory systems.
#
# We will use FHIR as:
#
# 1. We internally use FHIR as our [Canonical Data Model](https://www.enterpriseintegrationpatterns.com/patterns/messaging/CanonicalDataModel.html). The link provides a brief description of the decision behind this (the book has a more comprehensive description).
# 2. The tooling to support FHIR models is quite extensive.
#
# ## HL7 v2 vrs FHIR
#
# We don't view v2 and FHIR as competing. HL7 v2 is primarily a workflow interaction standard that supports asynchronous input/output. FHIR, on the other hand, is more focused on REST API interactions for querying data, which is something HL7 v2 doesn't support (well). As mentioned previously, we also use FHIR as the master data model as it can be converted to other standards such as HL7 v2 and XDS quite easily.

# %% [markdown]
# ## Consultation Writeback
#
# The writeback is a complex workflow. The diagram below is the intitial design for the updated writeback which includes the ability to send to GP Practices which don't use virtually via GP Connect Send Document.
#
# ![Alt text](../images/Writeback.drawio.png)
#
# ### Application - Clinical Process
#
# A practitioner:
#
# - GP - creates a clinical management plan
# - Pharmacist - creates a consultation note
#
# Both are stored in the Clinical Data Repository (FHIR Repository) and then a FHIR Task is created with status `requested`, requesting the consultation to be sent to the patient's GP.
#
# ### Workflow
#
# Tasks are polled from the FHIR Repository. For each Task:
#
# - **Extract Encounter**. Read consultation from the FHIR Repository and update FHIR Task to `accepted`
# - **Validate** TODO Use FHIR Validation to ensure it is valid. If not reject (and set Task.status to rejected)
# - **Get PDS Record** TODO Lookup Patients GP from PDS (**NEW**)
# - **Lookup Endpoint**  TODO Get Endpoint details to check to see if this is a local delivery.
# - If **EMIS (local delivery)**
#   - TODO Check for duplicates
#   - Convert to EMISOpen
#   - Send consultation to EMIS via IM1 Transaction
# - elseIf **TPP (local delivery)**
#   - Convert to TPP
#   - Send consultation to TPP via IM1 Transaction
# - Else
#   - Convert to a FHIR Document (**NEW**)
#   - Convert FHIR Document to PDF (**NEW**)
#   - Send consultation to GP Practice via MESH (workflow: GP Connect)
# - Update FHIR Task to `completed`.
#
# Note: For conformance reasons, a pharmacist should not use IM1 Transaction for
#
# Exceptions result in the FHIR Task status being changed to `cancelled`, validation errors have `failed` status

# %% [markdown]
# ### Example set up
#
# This gets a previously completed task and resets it
#
# 1. This is `GET Task\8b12d352-b2dc-4647-a544-ea2ed30011e1`
# 2. update `status` to `accepted`
# 3. Update the Task via `POST Task\8b12d352-b2dc-4647-a544-ea2ed30011e1`

# %%
import requests
import json
import time

headersCDR = { "Accept": "application/fhir+json"}

cdrFHIRUrl = "http://localhost:8180/CDR/FHIR/R4"

tasks = []
# first is already present on emis, 2nd should fail
for taskid in ['8b12d352-b2dc-4647-a544-ea2ed30011e1','17eb465f-3c31-48df-b6be-37600e15712c']:
    response = requests.get(cdrFHIRUrl + '/Task/' + taskid,headers=headersCDR)
    if response.status_code == 200:
        taskJSON = json.loads(response.text)
        taskJSON['status'] = 'accepted'
        headersCDR = {"Content-Type": "application/fhir+json", "Accept": "application/fhir+json"}
        response = requests.put(cdrFHIRUrl + '/Task/'+taskid,json.dumps(taskJSON),headers=headersCDR)
        print(response.text)
# Out:
# {
#   "resourceType": "Task",
#   "id": "8b12d352-b2dc-4647-a544-ea2ed30011e1",
#   "meta": {
#     "versionId": "380",
#     "lastUpdated": "2025-06-26T11:54:16.083Z"
#   },
#   "identifier": [ {
#     "system": "https://fhir.virtually.healthcare/Id/Task",
#     "value": "537fd315-8a60-4c02-a96e-473bd04a138d"
#   } ],
#   "status": "accepted",
#   "intent": "order",
#   "priority": "routine",
#   "code": {
#     "coding": [ {
#       "system": "http://fhir.virtuallyhealthcare.co.uk/CodeSystem/tasks",
#       "code": "WRITEBACK",
#       "display": "Consultation Write Back"
#     } ]
#   },
#   "focus": {
#     "reference": "Encounter/3493d264-ab4e-4794-9622-555ed16b75aa",
#     "identifier": {
#       "system": "https://fhir.virtually.healthcare/Id/Encounter",
#       "value": "d3aa0f25-6ceb-4baf-bb4f-8f53170c5231"
#     }
#   },
#   "for": {
#     "reference": "Patient/2cdce27e-9398-4367-8719-d872710e8e63"
#   },
#   "authoredOn": "2025-05-19T15:43:08+00:00",
#   "owner": {
#     "reference": "Organization/61a55cac-08d5-4cf8-a4d5-581f50962a82",
#     "identifier": {
#       "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#       "value": "F83004"
#     }
#   },
#   "note": [ {
#     "time": "2025-05-19T15:44:09+00:00",
#     "text": "Consultation written back to EPR system"
#   }, {
#     "time": "2025-06-23T06:25:22+00:00",
#     "text": "Moved from failure list to rejected"
#   }, {
#     "time": "2025-06-23T06:55:56+00:00",
#     "text": "Consultation written back to EPR system"
#   } ],
#   "input": [ {
#     "type": {
#       "text": "ResourceReference"
#     },
#     "valueReference": {
#       "reference": "QuestionnaireResponse/238c8ff7-f5d6-47be-a2ca-218c8732d68d"
#     }
#   } ],
#   "output": [ {
#     "type": {
#       "coding": [ {
#         "code": "WRITEBACK"
#       } ]
#     },
#     "valueString": "\n<MedicalRecord PatientID=\"500837\" xmlns=\"http://www.e-mis.com/emisopen/MedicalRecord\">\n    <ConsultationList>\n        <Consultation>\n            <GUID>d3aa0f25-6ceb-4baf-bb4f-8f53170c5231</GUID>\n            <AssignedDate>19/05/2025 15:43:05</AssignedDate>\n            <UserID>\n                <RefID>5885</RefID>\n            </UserID>\n            <LocationTypeID>\n                <RefID>307321000000107</RefID>\n            </LocationTypeID>\n            <OriginalAuthor>\n                <User>\n                    <RefID>5885</RefID>\n                </User>\n            </OriginalAuthor>\n            <ElementList>\n                <ConsultationElement>\n                    <RefID>1</RefID>\n                    <Header>\n                        <Term>Comment</Term>\n                    </Header>\n                    <Event>\n                        <RefID>1</RefID>\n                        <GUID>ae35314d-332f-4cda-b3ff-36b30497f73d</GUID>\n                        <AssignedDate>19/05/2025 15:43:05</AssignedDate>\n                        <AuthorID>\n                            <RefID>5885</RefID>\n                        </AuthorID>\n                        <OriginalAuthor>\n                            <User>\n                                <RefID>5885</RefID>\n                            </User>\n                        </OriginalAuthor>\n                        <DisplayTerm>Consultation Type</DisplayTerm>\n                        <DescriptiveText>Practitioner completed management plan</DescriptiveText>\n                    </Event>\n                </ConsultationElement>\n                <ConsultationElement>\n                    <RefID>2</RefID>\n                    <Header>\n                        <Term>Comment</Term>\n                    </Header>\n                    <Event>\n                        <RefID>1</RefID>\n                        <GUID>b55bd381-7846-4890-bde7-bea7a27e6948</GUID>\n                        <AssignedDate>19/05/2025 15:43:05</AssignedDate>\n                        <AuthorID>\n                            <RefID>5885</RefID>\n                        </AuthorID>\n                        <OriginalAuthor>\n                            <User>\n                                <RefID>5885</RefID>\n                            </User>\n                        </OriginalAuthor>\n                        <DisplayTerm>Comments and advice</DisplayTerm>\n                        <DescriptiveText>This is to see if writing back works</DescriptiveText>\n                    </Event>\n                </ConsultationElement>\n                <ConsultationElement>\n                    <RefID>3</RefID>\n                    <Header>\n                        <Term>Comment</Term>\n                    </Header>\n                    <Event>\n                        <RefID>1</RefID>\n                        <GUID>7e9aaa22-ee18-4bd7-9e5d-74e95746bf2b</GUID>\n                        <AssignedDate>19/05/2025 15:43:05</AssignedDate>\n                        <AuthorID>\n                            <RefID>5885</RefID>\n                        </AuthorID>\n                        <OriginalAuthor>\n                            <User>\n                                <RefID>5885</RefID>\n                            </User>\n                        </OriginalAuthor>\n                        <DisplayTerm>Important red flags to be aware of</DisplayTerm>\n                        <DescriptiveText>let me see the flags</DescriptiveText>\n                    </Event>\n                </ConsultationElement>\n                <ConsultationElement>\n                    <RefID>5</RefID>\n                    <Header>\n                        <Term>Comment</Term>\n                    </Header>\n                    <Event>\n                        <RefID>1</RefID>\n                        <GUID>9f3ba40e-c58f-4bac-aed4-e4eb317ee070</GUID>\n                        <AssignedDate>19/05/2025 15:43:05</AssignedDate>\n              ...
#   } ]
# }
# {
#   "resourceType": "Task",
#   "id": "17eb465f-3c31-48df-b6be-37600e15712c",
#   "meta": {
#     "versionId": "155",
#     "lastUpdated": "2025-06-26T11:54:16.480Z"
#   },
#   "identifier": [ {
#     "system": "https://fhir.virtually.healthcare/Id/Task",
#     "value": "8b6bba41-5085-4127-b785-9bc9b615a37e"
#   } ],
#   "status": "accepted",
#   "intent": "order",
#   "priority": "routine",
#   "code": {
#     "coding": [ {
#       "system": "http://fhir.virtuallyhealthcare.co.uk/CodeSystem/tasks",
#       "code": "WRITEBACK",
#       "display": "Consultation Write Back"
#     } ]
#   },
#   "focus": {
#     "reference": "Encounter/ffc6c3d6-b00e-4954-8431-486188514529",
#     "identifier": {
#       "system": "https://fhir.virtually.healthcare/Id/Encounter",
#       "value": "f7ff9fd2-11f7-4a4e-9d84-dfccc669c7e9"
#     }
#   },
#   "for": {
#     "reference": "Patient/f3501365-9b30-4fb5-8729-ac4cdf56ce58"
#   },
#   "authoredOn": "2025-03-17T23:09:27+00:00",
#   "owner": {
#     "reference": "Organization/61a55cac-08d5-4cf8-a4d5-581f50962a82",
#     "identifier": {
#       "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#       "value": "F83004"
#     }
#   },
#   "note": [ {
#     "time": "2025-03-17T23:10:36+00:00",
#     "text": "Technical error"
#   }, {
#     "time": "2025-03-17T23:11:28+00:00",
#     "text": "Moved from failure list accept list for retry"
#   }, {
#     "time": "2025-03-17T23:12:34+00:00",
#     "text": "Technical error"
#   }, {
#     "time": "2025-03-17T23:13:29+00:00",
#     "text": "Moved from failure list accept list for retry"
#   }, {
#     "time": "2025-03-17T23:14:34+00:00",
#     "text": "Technical error"
#   }, {
#     "time": "2025-03-17T23:15:28+00:00",
#     "text": "Moved from failure list accept list for retry"
#   }, {
#     "time": "2025-03-17T23:16:29+00:00",
#     "text": "Technical error"
#   }, {
#     "time": "2025-03-17T23:17:28+00:00",
#     "text": "Moved from failure list accept list for retry"
#   }, {
#     "time": "2025-03-17T23:18:29+00:00",
#     "text": "Technical error"
#   } ],
#   "input": [ {
#     "type": {
#       "text": "ResourceReference"
#     },
#     "valueReference": {
#       "reference": "QuestionnaireResponse/d635f644-ecaa-48d4-9e36-c562b50f0a71"
#     }
#   } ]
# }

# %%
# Due to way FHIRWorks is built we need to pause so that the update is processed

time.sleep(5)

# %% [markdown]
# ### Get writeback tasks

# %%
import requests
import json

headersCDR = { "Accept": "application/fhir+json"}

cdrFHIRUrl = "http://localhost:8180/CDR/FHIR/R4"


parameters = {'_sort' : '-authored-on',
              'authored-on': 'gt2023-01-01',
              'status': 'accepted'}

tasks = []
response = requests.get(cdrFHIRUrl + '/Task',parameters,headers=headersCDR)
if response.status_code == 200:
    tasksJSON = json.loads(response.text)
    if 'entry' in tasksJSON:
        for entry in tasksJSON['entry']:
            if 'resource' in entry:
                print(entry['resource'])
                tasks.append(entry['resource'])
# Out:
# {'resourceType': 'Task', 'id': '8b12d352-b2dc-4647-a544-ea2ed30011e1', 'meta': {'versionId': '380', 'lastUpdated': '2025-06-26T11:54:16.083Z'}, 'identifier': [{'system': 'https://fhir.virtually.healthcare/Id/Task', 'value': '537fd315-8a60-4c02-a96e-473bd04a138d'}], 'status': 'accepted', 'intent': 'order', 'priority': 'routine', 'code': {'coding': [{'system': 'http://fhir.virtuallyhealthcare.co.uk/CodeSystem/tasks', 'code': 'WRITEBACK', 'display': 'Consultation Write Back'}]}, 'focus': {'reference': 'Encounter/3493d264-ab4e-4794-9622-555ed16b75aa', 'identifier': {'system': 'https://fhir.virtually.healthcare/Id/Encounter', 'value': 'd3aa0f25-6ceb-4baf-bb4f-8f53170c5231'}}, 'for': {'reference': 'Patient/2cdce27e-9398-4367-8719-d872710e8e63'}, 'authoredOn': '2025-05-19T15:43:08+00:00', 'owner': {'reference': 'Organization/61a55cac-08d5-4cf8-a4d5-581f50962a82', 'identifier': {'system': 'https://fhir.nhs.uk/Id/ods-organization-code', 'value': 'F83004'}}, 'note': [{'time': '2025-05-19T15:44:09+00:00', 'text': 'Consultation written back to EPR system'}, {'time': '2025-06-23T06:25:22+00:00', 'text': 'Moved from failure list to rejected'}, {'time': '2025-06-23T06:55:56+00:00', 'text': 'Consultation written back to EPR system'}], 'input': [{'type': {'text': 'ResourceReference'}, 'valueReference': {'reference': 'QuestionnaireResponse/238c8ff7-f5d6-47be-a2ca-218c8732d68d'}}], 'output': [{'type': {'coding': [{'code': 'WRITEBACK'}]}, 'valueString': '\n<MedicalRecord PatientID="500837" xmlns="http://www.e-mis.com/emisopen/MedicalRecord">\n    <ConsultationList>\n        <Consultation>\n            <GUID>d3aa0f25-6ceb-4baf-bb4f-8f53170c5231</GUID>\n            <AssignedDate>19/05/2025 15:43:05</AssignedDate>\n            <UserID>\n                <RefID>5885</RefID>\n            </UserID>\n            <LocationTypeID>\n                <RefID>307321000000107</RefID>\n            </LocationTypeID>\n            <OriginalAuthor>\n                <User>\n                    <RefID>5885</RefID>\n                </User>\n            </OriginalAuthor>\n            <ElementList>\n                <ConsultationElement>\n                    <RefID>1</RefID>\n                    <Header>\n                        <Term>Comment</Term>\n                    </Header>\n                    <Event>\n                        <RefID>1</RefID>\n                        <GUID>ae35314d-332f-4cda-b3ff-36b30497f73d</GUID>\n                        <AssignedDate>19/05/2025 15:43:05</AssignedDate>\n                        <AuthorID>\n                            <RefID>5885</RefID>\n                        </AuthorID>\n                        <OriginalAuthor>\n                            <User>\n                                <RefID>5885</RefID>\n                            </User>\n                        </OriginalAuthor>\n                        <DisplayTerm>Consultation Type</DisplayTerm>\n                        <DescriptiveText>Practitioner completed management plan</DescriptiveText>\n                    </Event>\n                </ConsultationElement>\n                <ConsultationElement>\n                    <RefID>2</RefID>\n                    <Header>\n                        <Term>Comment</Term>\n                    </Header>\n                    <Event>\n                        <RefID>1</RefID>\n                        <GUID>b55bd381-7846-4890-bde7-bea7a27e6948</GUID>\n                        <AssignedDate>19/05/2025 15:43:05</AssignedDate>\n                        <AuthorID>\n                            <RefID>5885</RefID>\n                        </AuthorID>\n                        <OriginalAuthor>\n                            <User>\n                                <RefID>5885</RefID>\n                            </User>\n                        </OriginalAuthor>\n                        <DisplayTerm>Comments and advice</DisplayTerm>\n                        <DescriptiveText>This is to see if writing back works</DescriptiveText>\n                    </Event ...
# {'resourceType': 'Task', 'id': '17eb465f-3c31-48df-b6be-37600e15712c', 'meta': {'versionId': '155', 'lastUpdated': '2025-06-26T11:54:16.480Z'}, 'identifier': [{'system': 'https://fhir.virtually.healthcare/Id/Task', 'value': '8b6bba41-5085-4127-b785-9bc9b615a37e'}], 'status': 'accepted', 'intent': 'order', 'priority': 'routine', 'code': {'coding': [{'system': 'http://fhir.virtuallyhealthcare.co.uk/CodeSystem/tasks', 'code': 'WRITEBACK', 'display': 'Consultation Write Back'}]}, 'focus': {'reference': 'Encounter/ffc6c3d6-b00e-4954-8431-486188514529', 'identifier': {'system': 'https://fhir.virtually.healthcare/Id/Encounter', 'value': 'f7ff9fd2-11f7-4a4e-9d84-dfccc669c7e9'}}, 'for': {'reference': 'Patient/f3501365-9b30-4fb5-8729-ac4cdf56ce58'}, 'authoredOn': '2025-03-17T23:09:27+00:00', 'owner': {'reference': 'Organization/61a55cac-08d5-4cf8-a4d5-581f50962a82', 'identifier': {'system': 'https://fhir.nhs.uk/Id/ods-organization-code', 'value': 'F83004'}}, 'note': [{'time': '2025-03-17T23:10:36+00:00', 'text': 'Technical error'}, {'time': '2025-03-17T23:11:28+00:00', 'text': 'Moved from failure list accept list for retry'}, {'time': '2025-03-17T23:12:34+00:00', 'text': 'Technical error'}, {'time': '2025-03-17T23:13:29+00:00', 'text': 'Moved from failure list accept list for retry'}, {'time': '2025-03-17T23:14:34+00:00', 'text': 'Technical error'}, {'time': '2025-03-17T23:15:28+00:00', 'text': 'Moved from failure list accept list for retry'}, {'time': '2025-03-17T23:16:29+00:00', 'text': 'Technical error'}, {'time': '2025-03-17T23:17:28+00:00', 'text': 'Moved from failure list accept list for retry'}, {'time': '2025-03-17T23:18:29+00:00', 'text': 'Technical error'}], 'input': [{'type': {'text': 'ResourceReference'}, 'valueReference': {'reference': 'QuestionnaireResponse/d635f644-ecaa-48d4-9e36-c562b50f0a71'}}]}

# %% [markdown]
# ### Get Consultation Note from CDR
#
# Extract the full encounter from the CDR

# %%
CDRRecords = []
for task in tasks:
    encounter = task['focus']['identifier']
    parameters = {'identifier' : encounter['system'] + '|' + encounter['value']}

    responseCDR = requests.get(cdrFHIRUrl + '/Encounter/$extract-collection',parameters,headers=headersCDR)
    if responseCDR.status_code == 200:
        print("======= Response from extract collection ========")
        print(responseCDR.text)
        CDRRecords.append({
            "response": responseCDR.text,
            "task": task
        })
# Out:
# ======= Response from extract collection ========
# {
#   "resourceType": "Bundle",
#   "type": "collection",
#   "entry": [ {
#     "fullUrl": "https://ek1wj5eye3.execute-api.eu-west-2.amazonaws.com/dev/Encounter/3493d264-ab4e-4794-9622-555ed16b75aa",
#     "resource": {
#       "resourceType": "Encounter",
#       "id": "3493d264-ab4e-4794-9622-555ed16b75aa",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2025-05-19T15:43:08.138Z"
#       },
#       "identifier": [ {
#         "system": "https://fhir.virtually.healthcare/Id/Encounter",
#         "value": "d3aa0f25-6ceb-4baf-bb4f-8f53170c5231"
#       } ],
#       "status": "finished",
#       "class": {
#         "system": "http://terminology.hl7.org/CodeSystem/v3-ActCode",
#         "code": "AMB",
#         "display": "ambulatory"
#       },
#       "type": [ {
#         "text": "Virtually video"
#       } ],
#       "subject": {
#         "reference": "Patient/2cdce27e-9398-4367-8719-d872710e8e63"
#       },
#       "participant": [ {
#         "individual": {
#           "reference": "PractitionerRole/8720bd06-6f81-454c-bf92-2be7f505a0e6"
#         }
#       } ],
#       "period": {
#         "start": "2025-05-20T05:00:00+01:00",
#         "end": "2025-05-20T05:10:00+01:00"
#       },
#       "location": [ {
#         "location": {
#           "reference": "Location/daabb4e8-dab2-4237-a957-122fe83e62a3"
#         }
#       } ]
#     }
#   }, {
#     "fullUrl": "https://ek1wj5eye3.execute-api.eu-west-2.amazonaws.com/dev/Patient/2cdce27e-9398-4367-8719-d872710e8e63",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "2cdce27e-9398-4367-8719-d872710e8e63",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2025-05-19T15:31:18.160Z"
#       },
#       "identifier": [ {
#         "use": "usual",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "MR"
#           } ]
#         },
#         "system": "https://emis.com/Id/Patient/DBID",
#         "value": "500837",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       }, {
#         "use": "official",
#         "type": {
#           "coding": [ {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "NH"
#           } ]
#         },
#         "system": "https://fhir.nhs.uk/Id/nhs-number",
#         "value": "7777777785"
#       } ],
#       "active": true,
#       "name": [ {
#         "family": "Mist",
#         "given": [ "Al" ],
#         "prefix": [ "Mr" ]
#       } ],
#       "gender": "male",
#       "birthDate": "1992-01-01",
#       "address": [ {
#         "line": [ "1", "Main Street" ],
#         "city": "London",
#         "postalCode": "EC2A 4AQ"
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Organization/61a55cac-08d5-4cf8-a4d5-581f50962a82",
#         "identifier": {
#           "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#           "value": "F83004"
#         }
#       } ]
#     }
#   }, {
#     "fullUrl": "https://ek1wj5eye3.execute-api.eu-west-2.amazonaws.com/dev/Location/daabb4e8-dab2-4237-a957-122fe83e62a3",
#     "resource": {
#       "resourceType": "Location",
#       "id": "daabb4e8-dab2-4237-a957-122fe83e62a3",
#       "meta": {
#         "versionId": "2",
#         "lastUpdated": "2022-05-21T06:11:28.867Z"
#       },
#       "identifier": [ {
#         "system": "https://fhir.virtually.healthcare/Id/Location",
#         "value": "bc5eb960-91c0-41f9-8ecf-f1f666f5a378"
#       } ],
#       "name": "Virtually video",
#       "type": [ {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "307321000000107",
#           "display": "Video-link encounter"
#         } ]
#       } ]
#     }
#   }, {
#     "fullUrl": "https://ek1wj5eye3.execute-api.eu-west-2.amazonaws.com/dev/PractitionerRole/8720bd06-6f81-454c-bf92-2be7f505a0e6",
#     "resource": {
#       "resourceType": "PractitionerRole",
#       "id": "8720bd06-6f81-454c-bf92-2be7f505a0e6",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2023-11-06T17:49:45.684Z"
#       },
#       "practitioner": {
#         "reference": "Practitioner/7045b8ec-2fcd-4a3f-b495-5e206bacdc7a"
#       },
#       "organization": {
#         "reference": "Organization/61a55cac-08d5-4cf8-a4d5-581f50962a82"
#       }
#     }
#   }, {
#     "fullUrl": "https://ek1wj5eye3.execute-api.eu-west-2.amazonaws.com/dev/QuestionnaireResponse/238c8ff7-f5d6-47be-a2ca-218c8732d68d",
#     "resource": {
#       "resourceType": "QuestionnaireResponse",
#       "id": "238c8ff7-f5d6-47be-a2ca-218c8732d68d",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2025-05-19T15:43:08.943Z"
#       },
#       "identifier": {
#         "system": "https://fhir.virtually.healthcare/Id/QuestionnaireResponse",
#         "value": "d3aa0f25-6ceb-4baf-bb4f-8f53170c5231"
#       },
#       "status": "completed",
#       "subject": {
#         "reference": "Patient/2cdce27e-9398-4367-8719-d872710e8e63"
#       },
#       "encounter": {
#         "reference": "Encounter/3493d264-ab4e-4794-9622-555ed16b75aa",
#         "identifier": {
#           "system": "https://fhir.virtually.healthcare/Id/Encounter",
#           "value": "d3aa0f25-6ceb-4baf-bb4f-8f53170c5231"
#         },
#         "display": "Practitioner completed management plan"
#       },
#       "authored": "2025-05-19T16:43:05+01:00",
#       "author": {
#         "reference": "PractitionerRole/8720bd06-6f81-454c-bf92-2be7f505a0e6"
#       },
#       "item": [ {
#         "linkId": "fat-1",
#         "text": "Comments and advice",
#         "answer": [ {
#           "valueString": "This is to see if writing back works"
#         } ]
#       }, {
#         "linkId": "fat-2",
#         "text": "Important red flags to be aware of",
#         "answer": [ {
#           "valueString": "let me see the flags"
#         } ]
#       }, {
#         "linkId": "fat-3",
#         "text": "Clinician shorthand notes"
#       }, {
#         "linkId": "fat-4",
#         "text": "My Condition",
#         "answer": [ {
#           "valueString": "Back Pain"
#         } ]
#       }, {
#         "linkId": "fat-5",
#         "text": "Radio Group",
#         "answer": [ {
#           "valueString": "Option 2 (med)"
#         } ]
#       }, {
#         "linkId": "fat-6",
#         "text": "Select",
#         "answer": [ {
#           "valueString": "Option 3 (high)"
#         } ]
#       }, {
#         "linkId": "fat-7",
#         "text": "Text Field",
#         "answer": [ {
#           "valueString": "some text here"
#         } ]
#       }, {
#         "linkId": "fat-8",
#         "text": "Text Area",
#         "answer": [ {
#           "valueString": "Possimus aperiam pl"
#         } ]
#       }, {
#         "linkId": "fat-9",
#         "text": "Checkbox Group",
#         "answer": [ {
#           "valueString": "Option 1, Option 3"
#         } ]
#       }, {
#         "linkId": "fat-10",
#         "text": "Date Field",
#         "answer": [ {
#           "valueString": "2025-05-09"
#         } ]
#       }, {
#         "linkId": "fat-11",
#         "text": "Number",
#         "answer": [ {
#           "valueString": "121"
#         } ]
#       }, {
#         "linkId": "fat-12",
#         "text": "File Upload"
#       }, {
#         "linkId": "fat-13",
#         "text": "Multi File Upload"
#       }, {
#         "item": [ {
#           "answer": [ {
#             "valueCoding": {
#               "system": "http://snomed.info/sct",
#               "code": "68566005",
#               "display": "UTI - Urinary tract infection"
#             }
#           } ],
#           "item": [ {
#             "linkId": "problemStatus",
#             "text": "Problem Status",
#             "answer": [ {
#               "valueBoolean": true
#             } ]
#           }, {
#             "linkId": "problemSignificance",
#             "text": "Problem Significance",
#             "answer": [ {
#               "valueInteger": 1
#             } ]
#           }, {
#             "linkId": "problemType",
#             "text": "Problem Type",
#             "answer": [ {
#               "valueInteger": 1
#             } ]
#           }, {
#             "linkId": "problemExpectedDuration",
#             "text": "Problem Expected Duration (days)",
#             "answer": [ {
#               "valueInteger": 84
#             } ]
#           } ]
#         } ]
#       } ]
#     }
#   } ]
# }
# ======= Response from extract collection ========
# {
#   "resourceType": "Bundle",
#   "type": "collection",
#   "entry": [ {
#     "fullUrl": "https://ek1wj5eye3.execute-api.eu-west-2.amazonaws.com/dev/Encounter/ffc6c3d6-b00e-4954-8431-486188514529",
#     "resource": {
#       "resourceType": "Encounter",
#       "id": "ffc6c3d6-b00e-4954-8431-486188514529",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2025-03-17T22:53:20.916Z"
#       },
#       "identifier": [ {
#         "system": "https://fhir.virtually.healthcare/Id/Encounter",
#         "value": "f7ff9fd2-11f7-4a4e-9d84-dfccc669c7e9"
#       } ],
#       "status": "finished",
#       "class": {
#         "system": "http://terminology.hl7.org/CodeSystem/v3-ActCode",
#         "code": "AMB",
#         "display": "ambulatory"
#       },
#       "type": [ {
#         "text": "Virtually virtually consult - patient request"
#       } ],
#       "subject": {
#         "reference": "Patient/f3501365-9b30-4fb5-8729-ac4cdf56ce58"
#       },
#       "participant": [ {
#         "individual": {
#           "reference": "PractitionerRole/a1c80a51-38c1-4435-9868-dca83d3cd543"
#         }
#       } ],
#       "period": {
#         "start": "2025-03-17T22:42:41+00:00",
#         "end": "2025-03-17T22:52:41+00:00"
#       },
#       "location": [ {
#         "location": {
#           "reference": "Location/2a927124-06f4-491b-8f94-d62cbc034616"
#         }
#       } ]
#     }
#   }, {
#     "fullUrl": "https://ek1wj5eye3.execute-api.eu-west-2.amazonaws.com/dev/Patient/f3501365-9b30-4fb5-8729-ac4cdf56ce58",
#     "resource": {
#       "resourceType": "Patient",
#       "id": "f3501365-9b30-4fb5-8729-ac4cdf56ce58",
#       "meta": {
#         "versionId": "2",
#         "lastUpdated": "2023-10-25T23:50:43.550Z"
#       },
#       "identifier": [ {
#         "system": "https://emis.com/Id/Patient/DBID",
#         "value": "500029"
#       }, {
#         "system": "https://fhir.nhs.uk/Id/nhs-number",
#         "value": "5465474637"
#       }, {
#         "system": "https://emis.com/Id/Patient/ID",
#         "value": "F83004-500029"
#       } ],
#       "active": true,
#       "name": [ {
#         "family": "Smith",
#         "given": [ "Anne" ],
#         "prefix": [ "Ms" ]
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "07720195794",
#         "use": "mobile"
#       } ],
#       "gender": "female",
#       "birthDate": "1992-03-04",
#       "address": [ {
#         "line": [ "98 House", "Test Street" ],
#         "city": "Town City",
#         "postalCode": "PE1 4YB"
#       } ],
#       "generalPractitioner": [ {
#         "reference": "Organization/61a55cac-08d5-4cf8-a4d5-581f50962a82",
#         "identifier": {
#           "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#           "value": "F83004"
#         }
#       } ]
#     }
#   }, {
#     "fullUrl": "https://ek1wj5eye3.execute-api.eu-west-2.amazonaws.com/dev/Location/2a927124-06f4-491b-8f94-d62cbc034616",
#     "resource": {
#       "resourceType": "Location",
#       "id": "2a927124-06f4-491b-8f94-d62cbc034616",
#       "meta": {
#         "versionId": "2",
#         "lastUpdated": "2022-05-21T06:12:50.942Z"
#       },
#       "identifier": [ {
#         "system": "https://fhir.virtually.healthcare/Id/Location",
#         "value": "c25fe93c-70df-4618-9aed-548bee0229e0"
#       } ],
#       "name": "Virtually adhoc",
#       "type": [ {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "185316007",
#           "display": "Indirect encounter"
#         } ]
#       } ]
#     }
#   }, {
#     "fullUrl": "https://ek1wj5eye3.execute-api.eu-west-2.amazonaws.com/dev/PractitionerRole/a1c80a51-38c1-4435-9868-dca83d3cd543",
#     "resource": {
#       "resourceType": "PractitionerRole",
#       "id": "a1c80a51-38c1-4435-9868-dca83d3cd543",
#       "meta": {
#         "versionId": "3",
#         "lastUpdated": "2024-11-26T01:19:17.799Z",
#         "tag": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v3-ActReason",
#           "code": "HTEST",
#           "display": "test health data"
#         } ]
#       },
#       "text": {
#         "status": "generated",
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">\n\t\t\t<p>\n\t\t\t\tDr HealthOnline Test is a Referring Practitioner for Acme Hospital from 1-Jan 2012 to 31-Mar\n\t\t\t\t2012\n\t\t\t</p>\n\t\t</div>"
#       },
#       "identifier": [ {
#         "system": "https://emis.com/Id/Practitioner/DBID",
#         "value": "3410"
#       } ],
#       "active": true,
#       "period": {
#         "start": "2012-01-01",
#         "end": "2012-03-31"
#       },
#       "practitioner": {
#         "reference": "Practitioner/fd527352-364a-483c-9610-2061ba1f22e5",
#         "display": "Dr HealthOnline Test"
#       },
#       "organization": {
#         "reference": "Organization/61a55cac-08d5-4cf8-a4d5-581f50962a82"
#       },
#       "code": [ {
#         "coding": [ {
#           "system": "http://terminology.hl7.org/CodeSystem/v2-0286",
#           "code": "RP"
#         } ]
#       } ],
#       "specialty": [ {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "408443003",
#           "display": "General medical practice"
#         } ]
#       } ],
#       "location": [ {
#         "reference": "Location/1",
#         "display": "South Wing, second floor"
#       } ],
#       "healthcareService": [ {
#         "reference": "HealthcareService/example"
#       } ],
#       "telecom": [ {
#         "system": "phone",
#         "value": "(03) 5555 6473",
#         "use": "work"
#       }, {
#         "system": "email",
#         "value": "adam.southern@example.org",
#         "use": "work"
#       } ],
#       "availableTime": [ {
#         "daysOfWeek": [ "mon", "tue", "wed" ],
#         "availableStartTime": "09:00:00",
#         "availableEndTime": "16:30:00"
#       }, {
#         "daysOfWeek": [ "thu", "fri" ],
#         "availableStartTime": "09:00:00",
#         "availableEndTime": "12:00:00"
#       } ],
#       "notAvailable": [ {
#         "description": "Adam will be on extended leave during May 2017",
#         "during": {
#           "start": "2017-05-01",
#           "end": "2017-05-20"
#         }
#       } ],
#       "availabilityExceptions": "Adam is generally unavailable on public holidays and during the Christmas/New Year break",
#       "endpoint": [ {
#         "reference": "Endpoint/example"
#       } ]
#     }
#   }, {
#     "fullUrl": "https://ek1wj5eye3.execute-api.eu-west-2.amazonaws.com/dev/QuestionnaireResponse/d635f644-ecaa-48d4-9e36-c562b50f0a71",
#     "resource": {
#       "resourceType": "QuestionnaireResponse",
#       "id": "d635f644-ecaa-48d4-9e36-c562b50f0a71",
#       "meta": {
#         "versionId": "1",
#         "lastUpdated": "2025-03-17T23:09:33.467Z"
#       },
#       "identifier": {
#         "system": "https://fhir.virtually.healthcare/Id/QuestionnaireResponse",
#         "value": "f7ff9fd2-11f7-4a4e-9d84-dfccc669c7e9"
#       },
#       "status": "completed",
#       "subject": {
#         "reference": "Patient/f3501365-9b30-4fb5-8729-ac4cdf56ce58"
#       },
#       "encounter": {
#         "reference": "Encounter/ffc6c3d6-b00e-4954-8431-486188514529",
#         "identifier": {
#           "system": "https://fhir.virtually.healthcare/Id/Encounter",
#           "value": "f7ff9fd2-11f7-4a4e-9d84-dfccc669c7e9"
#         },
#         "display": "Patient requested consultation via practice website."
#       },
#       "authored": "2025-03-17T22:42:41+00:00",
#       "author": {
#         "reference": "PractitionerRole/a1c80a51-38c1-4435-9868-dca83d3cd543"
#       },
#       "item": [ {
#         "linkId": "patient request",
#         "text": "Virtually consult: health concern",
#         "answer": [ {
#           "valueString": "Back Pain"
#         } ]
#       }, {
#         "linkId": "submitted by",
#         "text": "Submitted by:",
#         "answer": [ {
#           "valueString": "Clinician 1"
#         } ]
#       }, {
#         "linkId": "submitted date",
#         "text": "Submitted at:",
#         "answer": [ {
#           "valueString": "2025-03-17 22:42:41"
#         } ]
#       }, {
#         "linkId": "notes",
#         "text": "Notes:",
#         "answer": [ {
#           "valueString": "\n- type: Triage\n note: dfgdfg\n author: Clinician 1\n"
#         }, {
#           "valueString": "\n- type: Disposal\n note: sdfsdf\n author: Clinician 1\n"
#         } ]
#       }, {
#         "linkId": "triage",
#         "text": "Triage",
#         "answer": [ {
#           "valueString": "\nTriaged at: 17-03-2025 22:45\nTriaged by: Clinician 1\n\n"
#         } ]
#       }, {
#         "linkId": "disposal",
#         "text": "Disposal",
#         "answer": [ {
#           "valueString": "\nDepartment: practice\nAppointment: 18-03-2025 22:45\nAssigned to: Clinician 2\n\nActioned at: 17-03-2025 22:46\nActioned by: Clinician 1\n\n"
#         } ]
#       }, {
#         "linkId": "fat-7",
#         "text": "My Condition",
#         "answer": [ {
#           "valueString": "Unlisted condition"
#         } ]
#       }, {
#         "linkId": "fat-8",
#         "text": "How long have you had this episode?",
#         "answer": [ {
#           "valueString": "1"
#         } ]
#       }, {
#         "linkId": "fat-9",
#         "text": "Have you had it before? If so when was the last episode?",
#         "answer": [ {
#           "valueString": "2"
#         } ]
#       }, {
#         "linkId": "fat-10",
#         "text": "When do you recall first having back pain?",
#         "answer": [ {
#           "valueString": "dfg"
#         } ]
#       }, {
#         "linkId": "fat-11",
#         "text": "Does it affect your work, sleep, daily activities, walking or recreation?",
#         "answer": [ {
#           "valueString": "No"
#         } ]
#       }, {
#         "linkId": "fat-12",
#         "text": "What part of the back is the pain in?",
#         "answer": [ {
#           "valueString": "dfg"
#         } ]
#       }, {
#         "linkId": "fat-13",
#         "text": "Does it go down either leg? If so how far down?",
#         "answer": [ {
#           "valueString": "dfg"
#         } ]
#       }, {
#         "linkId": "fat-14",
#         "text": "Do you get numbness or tingling in the feet?",
#         "answer": [ {
#           "valueString": "No"
#         } ]
#       }, {
#         "linkId": "fat-15",
#         "text": "Have you been incontinent?",
#         "answer": [ {
#           "valueString": "No"
#         } ]
#       }, {
#         "linkId": "fat-16",
#         "text": "Which treatments have you tried this time?"
#       }, {
#         "linkId": "fat-17",
#         "text": "Which treatments have you found to work best?"
#       }, {
#         "linkId": "fat-18",
#         "text": "Have you had any side effects from any treatments you have tried?"
#       }, {
#         "linkId": "fat-19",
#         "text": "Have you had physio, osteopathy or chiropractic treatment? If so did any work?"
#       }, {
#         "linkId": "fat-20",
#         "text": "Have you had any injections into your back or back surgery?"
#       }, {
#         "linkId": "fat-21",
#         "text": "What are you seeking from this consultation (e.g. Prescription for pain relief or sick note)?"
#       } ]
#     }
#   } ]
# }

# %% [markdown]
# ### Convert to FHIR Message ADT_A04 (hard coded endpoint)

# %%
import uuid

FHIRMessages = []
for record in CDRRecords:
    resource = json.loads(record['response'])
    resource["type"] = "message"
    myuuid = uuid.uuid4()
    resource["identifier"] = {
        "system": "urn:ietf:rfc:3986",
        "value": 'urn:uuid:' + str(myuuid)
    }
    messageHeader = {
        "resourceType" : "MessageHeader",
        "eventCoding" : {
            "system" : "http://terminology.hl7.org/CodeSystem/v2-0003",
            "code" : "A04"
        },
        "destination" : [
            {
                "endpoint" : "http://ec2-18-130-139-120.eu-west-2.compute.amazonaws.com/emis",
                "receiver" : {
                    "identifier" : {
                        "system" : "https://fhir.nhs.uk/Id/ods-organization-code",
                        "value" : "F83004"
                    }
                }
            }
        ],
        "sender" : {
            "identifier" : {
                "system" : "https://fhir.nhs.uk/Id/ods-organization-code",
                "value" : "F83004"
            }
        },
        "source" : {
            "endpoint" : "http://ec2-18-130-139-120.eu-west-2.compute.amazonaws.com/emis"
        },
        "focus" : [
        ]
    }
    for entry in resource.get('entry', []):

       if 'resource' in entry:
           if 'resourceType' in entry['resource']:
               resourceType = entry['resource']['resourceType']
               if resourceType == 'Encounter':
                   print("Encounter")
                   messageHeader['focus'].append({
                       "reference" : entry['fullUrl'],
                       "type": "Encounter"
                   })
    resource["entry"].insert(0,{
        "fullUrl": "urn:uuid:" + str(myuuid),
        "resource": messageHeader
    })
    print(json.dumps(resource))
    FHIRMessages.append({
        "response" : json.dumps(resource),
        "task": record['task']
    })
# Out:
# Encounter
# {"resourceType": "Bundle", "type": "message", "entry": [{"fullUrl": "urn:uuid:979a7876-82f6-4163-b443-976e0b0cea43", "resource": {"resourceType": "MessageHeader", "eventCoding": {"system": "http://terminology.hl7.org/CodeSystem/v2-0003", "code": "A04"}, "destination": [{"endpoint": "http://ec2-18-130-139-120.eu-west-2.compute.amazonaws.com/emis", "receiver": {"identifier": {"system": "https://fhir.nhs.uk/Id/ods-organization-code", "value": "F83004"}}}], "sender": {"identifier": {"system": "https://fhir.nhs.uk/Id/ods-organization-code", "value": "F83004"}}, "source": {"endpoint": "http://ec2-18-130-139-120.eu-west-2.compute.amazonaws.com/emis"}, "focus": [{"reference": "https://ek1wj5eye3.execute-api.eu-west-2.amazonaws.com/dev/Encounter/3493d264-ab4e-4794-9622-555ed16b75aa", "type": "Encounter"}]}}, {"fullUrl": "https://ek1wj5eye3.execute-api.eu-west-2.amazonaws.com/dev/Encounter/3493d264-ab4e-4794-9622-555ed16b75aa", "resource": {"resourceType": "Encounter", "id": "3493d264-ab4e-4794-9622-555ed16b75aa", "meta": {"versionId": "1", "lastUpdated": "2025-05-19T15:43:08.138Z"}, "identifier": [{"system": "https://fhir.virtually.healthcare/Id/Encounter", "value": "d3aa0f25-6ceb-4baf-bb4f-8f53170c5231"}], "status": "finished", "class": {"system": "http://terminology.hl7.org/CodeSystem/v3-ActCode", "code": "AMB", "display": "ambulatory"}, "type": [{"text": "Virtually video"}], "subject": {"reference": "Patient/2cdce27e-9398-4367-8719-d872710e8e63"}, "participant": [{"individual": {"reference": "PractitionerRole/8720bd06-6f81-454c-bf92-2be7f505a0e6"}}], "period": {"start": "2025-05-20T05:00:00+01:00", "end": "2025-05-20T05:10:00+01:00"}, "location": [{"location": {"reference": "Location/daabb4e8-dab2-4237-a957-122fe83e62a3"}}]}}, {"fullUrl": "https://ek1wj5eye3.execute-api.eu-west-2.amazonaws.com/dev/Patient/2cdce27e-9398-4367-8719-d872710e8e63", "resource": {"resourceType": "Patient", "id": "2cdce27e-9398-4367-8719-d872710e8e63", "meta": {"versionId": "1", "lastUpdated": "2025-05-19T15:31:18.160Z"}, "identifier": [{"use": "usual", "type": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v2-0203", "code": "MR"}]}, "system": "https://emis.com/Id/Patient/DBID", "value": "500837", "assigner": {"identifier": {"system": "https://fhir.nhs.uk/Id/ods-organization-code", "value": "F83004"}}}, {"use": "official", "type": {"coding": [{"system": "http://terminology.hl7.org/CodeSystem/v2-0203", "code": "NH"}]}, "system": "https://fhir.nhs.uk/Id/nhs-number", "value": "7777777785"}], "active": true, "name": [{"family": "Mist", "given": ["Al"], "prefix": ["Mr"]}], "gender": "male", "birthDate": "1992-01-01", "address": [{"line": ["1", "Main Street"], "city": "London", "postalCode": "EC2A 4AQ"}], "generalPractitioner": [{"reference": "Organization/61a55cac-08d5-4cf8-a4d5-581f50962a82", "identifier": {"system": "https://fhir.nhs.uk/Id/ods-organization-code", "value": "F83004"}}]}}, {"fullUrl": "https://ek1wj5eye3.execute-api.eu-west-2.amazonaws.com/dev/Location/daabb4e8-dab2-4237-a957-122fe83e62a3", "resource": {"resourceType": "Location", "id": "daabb4e8-dab2-4237-a957-122fe83e62a3", "meta": {"versionId": "2", "lastUpdated": "2022-05-21T06:11:28.867Z"}, "identifier": [{"system": "https://fhir.virtually.healthcare/Id/Location", "value": "bc5eb960-91c0-41f9-8ecf-f1f666f5a378"}], "name": "Virtually video", "type": [{"coding": [{"system": "http://snomed.info/sct", "code": "307321000000107", "display": "Video-link encounter"}]}]}}, {"fullUrl": "https://ek1wj5eye3.execute-api.eu-west-2.amazonaws.com/dev/PractitionerRole/8720bd06-6f81-454c-bf92-2be7f505a0e6", "resource": {"resourceType": "PractitionerRole", "id": "8720bd06-6f81-454c-bf92-2be7f505a0e6", "meta": {"versionId": "1", "lastUpdated": "2023-11-06T17:49:45.684Z"}, "practitioner": {"reference": "Practitioner/7045b8ec-2fcd-4a3f-b495-5e206bacdc7a"}, "organization": {"reference": "Organization/61a55cac-08d5-4cf8-a4d5-581f50962a82"}}}, {"fullUrl": "https://ek1wj5eye3.execute-api.eu-west-2.amaz ...
# Encounter
# {"resourceType": "Bundle", "type": "message", "entry": [{"fullUrl": "urn:uuid:89840b98-63d0-4f07-94a7-dff0cb7304a8", "resource": {"resourceType": "MessageHeader", "eventCoding": {"system": "http://terminology.hl7.org/CodeSystem/v2-0003", "code": "A04"}, "destination": [{"endpoint": "http://ec2-18-130-139-120.eu-west-2.compute.amazonaws.com/emis", "receiver": {"identifier": {"system": "https://fhir.nhs.uk/Id/ods-organization-code", "value": "F83004"}}}], "sender": {"identifier": {"system": "https://fhir.nhs.uk/Id/ods-organization-code", "value": "F83004"}}, "source": {"endpoint": "http://ec2-18-130-139-120.eu-west-2.compute.amazonaws.com/emis"}, "focus": [{"reference": "https://ek1wj5eye3.execute-api.eu-west-2.amazonaws.com/dev/Encounter/ffc6c3d6-b00e-4954-8431-486188514529", "type": "Encounter"}]}}, {"fullUrl": "https://ek1wj5eye3.execute-api.eu-west-2.amazonaws.com/dev/Encounter/ffc6c3d6-b00e-4954-8431-486188514529", "resource": {"resourceType": "Encounter", "id": "ffc6c3d6-b00e-4954-8431-486188514529", "meta": {"versionId": "1", "lastUpdated": "2025-03-17T22:53:20.916Z"}, "identifier": [{"system": "https://fhir.virtually.healthcare/Id/Encounter", "value": "f7ff9fd2-11f7-4a4e-9d84-dfccc669c7e9"}], "status": "finished", "class": {"system": "http://terminology.hl7.org/CodeSystem/v3-ActCode", "code": "AMB", "display": "ambulatory"}, "type": [{"text": "Virtually virtually consult - patient request"}], "subject": {"reference": "Patient/f3501365-9b30-4fb5-8729-ac4cdf56ce58"}, "participant": [{"individual": {"reference": "PractitionerRole/a1c80a51-38c1-4435-9868-dca83d3cd543"}}], "period": {"start": "2025-03-17T22:42:41+00:00", "end": "2025-03-17T22:52:41+00:00"}, "location": [{"location": {"reference": "Location/2a927124-06f4-491b-8f94-d62cbc034616"}}]}}, {"fullUrl": "https://ek1wj5eye3.execute-api.eu-west-2.amazonaws.com/dev/Patient/f3501365-9b30-4fb5-8729-ac4cdf56ce58", "resource": {"resourceType": "Patient", "id": "f3501365-9b30-4fb5-8729-ac4cdf56ce58", "meta": {"versionId": "2", "lastUpdated": "2023-10-25T23:50:43.550Z"}, "identifier": [{"system": "https://emis.com/Id/Patient/DBID", "value": "500029"}, {"system": "https://fhir.nhs.uk/Id/nhs-number", "value": "5465474637"}, {"system": "https://emis.com/Id/Patient/ID", "value": "F83004-500029"}], "active": true, "name": [{"family": "Smith", "given": ["Anne"], "prefix": ["Ms"]}], "telecom": [{"system": "phone", "value": "07720195794", "use": "mobile"}], "gender": "female", "birthDate": "1992-03-04", "address": [{"line": ["98 House", "Test Street"], "city": "Town City", "postalCode": "PE1 4YB"}], "generalPractitioner": [{"reference": "Organization/61a55cac-08d5-4cf8-a4d5-581f50962a82", "identifier": {"system": "https://fhir.nhs.uk/Id/ods-organization-code", "value": "F83004"}}]}}, {"fullUrl": "https://ek1wj5eye3.execute-api.eu-west-2.amazonaws.com/dev/Location/2a927124-06f4-491b-8f94-d62cbc034616", "resource": {"resourceType": "Location", "id": "2a927124-06f4-491b-8f94-d62cbc034616", "meta": {"versionId": "2", "lastUpdated": "2022-05-21T06:12:50.942Z"}, "identifier": [{"system": "https://fhir.virtually.healthcare/Id/Location", "value": "c25fe93c-70df-4618-9aed-548bee0229e0"}], "name": "Virtually adhoc", "type": [{"coding": [{"system": "http://snomed.info/sct", "code": "185316007", "display": "Indirect encounter"}]}]}}, {"fullUrl": "https://ek1wj5eye3.execute-api.eu-west-2.amazonaws.com/dev/PractitionerRole/a1c80a51-38c1-4435-9868-dca83d3cd543", "resource": {"resourceType": "PractitionerRole", "id": "a1c80a51-38c1-4435-9868-dca83d3cd543", "meta": {"versionId": "3", "lastUpdated": "2024-11-26T01:19:17.799Z", "tag": [{"system": "http://terminology.hl7.org/CodeSystem/v3-ActReason", "code": "HTEST", "display": "test health data"}]}, "text": {"status": "generated", "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">\n\t\t\t<p>\n\t\t\t\tDr HealthOnline Test is a Referring Practitioner for Acme Hospital from 1-Jan 2012 to 31-Mar\n\t\t\t\t2012\n\t\t\t</p>\n\t\t</div>"}, "identifier": [{"sy ...

# %% [markdown]
# ### Legacy QuestionnaireResponse Fix
#
# New write will have more defined structure. Older writebacks need converting the to new structure.

# %%
import copy

def LegacyQuestionnaireResponseConversion(questionnaireResponse):
    questionnaireResponse['questionnaire'] = "https://fhir.virtually.healthcare/Questionnaire/ClinicalManagementPlan"
    newQR = copy.deepcopy(questionnaireResponse)
    newQR['item'] = [{
        "linkId": "LOINC/61149-1",
        "text": "Comments and advice",
        "item": []
    }]
    # missing linkId - assume it's the problem section
    problems = {
        "linkId": "LOINC/11450-4",
        "text": "Problem list",
        "item": []
    }
    problemsFound = False
    for item in questionnaireResponse.get('item', []):
        # exiting fat entries are plain questions and answers
        if 'answer' in item:
            newQR['item'][0]['item'].append({
                "linkId" : "questions",
                "item": [{
                        "linkId": "question",
                        "answer": [ {
                            "valueString": item['text']
                        }]
                    },
                    {
                        "linkId": "answer",
                        "answer": [ {
                            "valueString": item['answer'][0]["valueString"]
                        }]
                    }]
            })
        # problem management comes as a set of subitems.
        if 'item' in item:
            problem = {
                "linkId": "problem",
                "text": "Problem",
                "item": []
            }
            problemFound = False
            for problemitem in item.get('item', []):
                if 'linkId' not in problemitem:
                    newitem = {
                        'linkId' : 'problemCode',
                        'text' : "Problem Code",
                        'answer' : problemitem['answer']
                    }
                    problem['item'].append(newitem)
                if 'item' in problemitem:
                    for subitem in problemitem.get('item', []):
                        if subitem['linkId'] == 'problemStatus' or subitem['linkId'] == 'problemSignifiance' or subitem['linkId'] == 'problemType' or subitem['linkId'] == 'problemExpectedDuration':
                            problem['item'].append(subitem)
                            problemFound = True
            if problemFound:
                problems['item'].append(problem)
                problemsFound = True

    if problemsFound:
        newQR['item'].append(problems)
    print(json.dumps(newQR))
    return newQR

for record in FHIRMessages:
    # begin fix the bundle
    resource = json.loads(record['response'])
    id = 0
    for entry in resource.get('entry', []):
        id += 1
        if 'resource' in entry:
            if 'resourceType' in entry['resource']:
                resourceType = entry['resource']['resourceType']
                if resourceType == 'QuestionnaireResponse':
                    # add in the questionnaire
                    if 'questionnaire' not in entry['resource']:
                        # legacy entries do not have a questionnaire
                        entry['resource'] = LegacyQuestionnaireResponseConversion(entry['resource'])
    record['response'] = json.dumps(resource)
# Out:
# {"resourceType": "QuestionnaireResponse", "id": "238c8ff7-f5d6-47be-a2ca-218c8732d68d", "meta": {"versionId": "1", "lastUpdated": "2025-05-19T15:43:08.943Z"}, "identifier": {"system": "https://fhir.virtually.healthcare/Id/QuestionnaireResponse", "value": "d3aa0f25-6ceb-4baf-bb4f-8f53170c5231"}, "status": "completed", "subject": {"reference": "Patient/2cdce27e-9398-4367-8719-d872710e8e63"}, "encounter": {"reference": "Encounter/3493d264-ab4e-4794-9622-555ed16b75aa", "identifier": {"system": "https://fhir.virtually.healthcare/Id/Encounter", "value": "d3aa0f25-6ceb-4baf-bb4f-8f53170c5231"}, "display": "Practitioner completed management plan"}, "authored": "2025-05-19T16:43:05+01:00", "author": {"reference": "PractitionerRole/8720bd06-6f81-454c-bf92-2be7f505a0e6"}, "item": [{"linkId": "LOINC/61149-1", "text": "Comments and advice", "item": [{"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "Comments and advice"}]}, {"linkId": "answer", "answer": [{"valueString": "This is to see if writing back works"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "Important red flags to be aware of"}]}, {"linkId": "answer", "answer": [{"valueString": "let me see the flags"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "My Condition"}]}, {"linkId": "answer", "answer": [{"valueString": "Back Pain"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "Radio Group"}]}, {"linkId": "answer", "answer": [{"valueString": "Option 2 (med)"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "Select"}]}, {"linkId": "answer", "answer": [{"valueString": "Option 3 (high)"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "Text Field"}]}, {"linkId": "answer", "answer": [{"valueString": "some text here"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "Text Area"}]}, {"linkId": "answer", "answer": [{"valueString": "Possimus aperiam pl"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "Checkbox Group"}]}, {"linkId": "answer", "answer": [{"valueString": "Option 1, Option 3"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "Date Field"}]}, {"linkId": "answer", "answer": [{"valueString": "2025-05-09"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "Number"}]}, {"linkId": "answer", "answer": [{"valueString": "121"}]}]}]}, {"linkId": "LOINC/11450-4", "text": "Problem list", "item": [{"linkId": "problem", "text": "Problem", "item": [{"linkId": "problemCode", "text": "Problem Code", "answer": [{"valueCoding": {"system": "http://snomed.info/sct", "code": "68566005", "display": "UTI - Urinary tract infection"}}]}, {"linkId": "problemStatus", "text": "Problem Status", "answer": [{"valueBoolean": true}]}, {"linkId": "problemType", "text": "Problem Type", "answer": [{"valueInteger": 1}]}, {"linkId": "problemExpectedDuration", "text": "Problem Expected Duration (days)", "answer": [{"valueInteger": 84}]}]}]}], "questionnaire": "https://fhir.virtually.healthcare/Questionnaire/ClinicalManagementPlan"}
# {"resourceType": "QuestionnaireResponse", "id": "d635f644-ecaa-48d4-9e36-c562b50f0a71", "meta": {"versionId": "1", "lastUpdated": "2025-03-17T23:09:33.467Z"}, "identifier": {"system": "https://fhir.virtually.healthcare/Id/QuestionnaireResponse", "value": "f7ff9fd2-11f7-4a4e-9d84-dfccc669c7e9"}, "status": "completed", "subject": {"reference": "Patient/f3501365-9b30-4fb5-8729-ac4cdf56ce58"}, "encounter": {"reference": "Encounter/ffc6c3d6-b00e-4954-8431-486188514529", "identifier": {"system": "https://fhir.virtually.healthcare/Id/Encounter", "value": "f7ff9fd2-11f7-4a4e-9d84-dfccc669c7e9"}, "display": "Patient requested consultation via practice website."}, "authored": "2025-03-17T22:42:41+00:00", "author": {"reference": "PractitionerRole/a1c80a51-38c1-4435-9868-dca83d3cd543"}, "item": [{"linkId": "LOINC/61149-1", "text": "Comments and advice", "item": [{"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "Virtually consult: health concern"}]}, {"linkId": "answer", "answer": [{"valueString": "Back Pain"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "Submitted by:"}]}, {"linkId": "answer", "answer": [{"valueString": "Clinician 1"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "Submitted at:"}]}, {"linkId": "answer", "answer": [{"valueString": "2025-03-17 22:42:41"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "Notes:"}]}, {"linkId": "answer", "answer": [{"valueString": "\n- type: Triage\n note: dfgdfg\n author: Clinician 1\n"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "Triage"}]}, {"linkId": "answer", "answer": [{"valueString": "\nTriaged at: 17-03-2025 22:45\nTriaged by: Clinician 1\n\n"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "Disposal"}]}, {"linkId": "answer", "answer": [{"valueString": "\nDepartment: practice\nAppointment: 18-03-2025 22:45\nAssigned to: Clinician 2\n\nActioned at: 17-03-2025 22:46\nActioned by: Clinician 1\n\n"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "My Condition"}]}, {"linkId": "answer", "answer": [{"valueString": "Unlisted condition"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "How long have you had this episode?"}]}, {"linkId": "answer", "answer": [{"valueString": "1"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "Have you had it before? If so when was the last episode?"}]}, {"linkId": "answer", "answer": [{"valueString": "2"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "When do you recall first having back pain?"}]}, {"linkId": "answer", "answer": [{"valueString": "dfg"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "Does it affect your work, sleep, daily activities, walking or recreation?"}]}, {"linkId": "answer", "answer": [{"valueString": "No"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "What part of the back is the pain in?"}]}, {"linkId": "answer", "answer": [{"valueString": "dfg"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "Does it go down either leg? If so how far down?"}]}, {"linkId": "answer", "answer": [{"valueString": "dfg"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "Do you get numbness or tingling in the feet?"}]}, {"linkId": "answer", "answer": [{"valueString": "No"}]}]}, {"linkId": "questions", "item": [{"linkId": "question", "answer": [{"valueString": "Have you been incontinent?"}]}, {"linkId": "answer", "answer": [{"valueString": "No"}]}]}]}], "questionnaire": "https://fhir.virtually.healthcare/Questionnaire/ClinicalManagementPlan"}

# %% [markdown]
# ### Check Consultation does not already exist
#
# TODO Check for duplicates. Should be a call to the Composition endpoint

# %%
emisFHIRUrl = "http://localhost:8180/EMIS/FHIR/R4"
headersEMIS = {"Accept": "application/fhir+json",
               "ODS_CODE": "F83004"}

for record in CDRRecords:
    resource = json.loads(record['response'])
    id = 0
    patientId = ''
    encounterId = ''
    for entry in resource.get('entry', []):
        id += 1
        if 'resource' in entry:
            if 'resourceType' in entry['resource']:
                resourceType = entry['resource']['resourceType']
                if resourceType == 'Patient':
                    if 'identifier' in entry['resource']:
                        for identifier in entry['resource'].get('identifier', []):
                            if 'system' in identifier and identifier['system'] == 'https://emis.com/Id/Patient/DBID':
                                patientId = identifier['value']
                    print(patientId)
                if resourceType == 'Encounter':
                    if 'identifier' in entry['resource']:
                        for identifier in entry['resource'].get('identifier', []):
                            if 'system' in identifier and identifier['system'] == 'https://fhir.virtually.healthcare/Id/Encounter':
                                encounterId = identifier['value']
                    print(encounterId)
    if (patientId != '' and encounterId != ''):
        url = emisFHIRUrl + f'/Composition?patient={patientId}'
        responseComposition = requests.get(url, headers=headersEMIS)
        print(responseComposition.text)
        resource = json.loads(responseComposition.text)
        for entry in resource.get('entry', []):
            if 'resourceType' in entry['resource'] and entry['resource']['resourceType'] == 'Composition':
                print('Have composition')
                if 'encounter' in entry['resource'] and 'identifier' in entry['resource']['encounter'] and entry['resource']['encounter']['identifier']['value'] == encounterId :
                    print('DUPLICATE SHOULD GRACEFULLY FINISH')
# Out:
# d3aa0f25-6ceb-4baf-bb4f-8f53170c5231
# 500837
# {
#   "resourceType": "Bundle",
#   "id": "d0f1ce6f-7c41-47b3-b287-98c59870a37f",
#   "meta": {
#     "lastUpdated": "2025-06-26T11:54:18.068+00:00"
#   },
#   "type": "searchset",
#   "total": 0,
#   "link": [ {
#     "relation": "self",
#     "url": "http://localhost:8180/EMIS/FHIR/R4/Composition?patient=500837"
#   } ]
# }
# f7ff9fd2-11f7-4a4e-9d84-dfccc669c7e9
# 500029
# {
#   "resourceType": "Bundle",
#   "id": "f06689a3-7d20-482c-8fd7-5e93741d43a1",
#   "meta": {
#     "lastUpdated": "2025-06-26T11:54:19.758+00:00"
#   },
#   "type": "searchset",
#   "total": 127,
#   "link": [ {
#     "relation": "self",
#     "url": "http://localhost:8180/EMIS/FHIR/R4/Composition?patient=500029"
#   }, {
#     "relation": "next",
#     "url": "http://localhost:8180/EMIS/FHIR/R4?_getpages=d8cc9040-6999-46a1-a450-7fa952874428&_getpagesoffset=20&_count=20&_pretty=true&_bundletype=searchset"
#   } ],
#   "entry": [ {
#     "fullUrl": "http://localhost:8180/EMIS/FHIR/R4/Composition/f7ff9fd2-11f7-4a4e-9d84-dfccc669c7e9",
#     "resource": {
#       "resourceType": "Composition",
#       "id": "f7ff9fd2-11f7-4a4e-9d84-dfccc669c7e9",
#       "identifier": {
#         "use": "usual",
#         "system": "https://tools.ietf.org/html/rfc4122",
#         "value": "42b1c6f5-27b7-43a0-91ca-7c25f5aa5969",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       },
#       "status": "final",
#       "type": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "823651000000106",
#           "display": "Clinical note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/500029",
#         "type": "Patient"
#       },
#       "encounter": {
#         "reference": "Encounter/f7ff9fd2-11f7-4a4e-9d84-dfccc669c7e9",
#         "identifier": {
#           "system": "https://emis.com/Id/Consultation/GUID",
#           "value": "f7ff9fd2-11f7-4a4e-9d84-dfccc669c7e9",
#           "assigner": {
#             "identifier": {
#               "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#               "value": "F83004"
#             }
#           }
#         }
#       },
#       "date": "2025-03-17T22:42:41+00:00",
#       "author": [ {
#         "reference": "Practitioner/f9e83fad-2302-44e8-b659-f2941d44cab1",
#         "type": "Practitioner",
#         "identifier": {
#           "system": "https://emis.com/Id/Practitioner/GUID",
#           "value": "f9e83fad-2302-44e8-b659-f2941d44cab1"
#         },
#         "display": "Mr Appointments NEAS"
#       } ],
#       "title": "Clinical note",
#       "section": [ {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Consultation Type <i>Patient requested consultation via practice website.</i></p><p>Virtually consult: health concern <i>Back Pain</i></p><p>Submitted by: <i>Clinician 1</i></p><p>Submitted at: <i>2025-03-17 22:42:41</i></p><p>Notes: <i>\n- type: Triage\n note: dfgdfg\n author: Clinician 1\n</i></p><p>Triage <i>\nTriaged at: 17-03-2025 22:45\nTriaged by: Clinician 1\n\n</i></p><p>Disposal <i>\nDepartment: practice\nAppointment: 18-03-2025 22:45\nAssigned to: Clinician 2\n\nActioned at: 17-03-2025 22:46\nActioned by: Clinician 1\n\n</i></p><p>My Condition <i>Unlisted condition</i></p><p>How long have you had this episode? <i>1</i></p><p>Have you had it before? If so when was the last episode? <i>2</i></p><p>When do you recall first having back pain? <i>dfg</i></p><p>Does it affect your work, sleep, daily activities, walking or recreation? <i>No</i></p><p>What part of the back is the pain in? <i>dfg</i></p><p>Does it go down either leg? If so how far down? <i>dfg</i></p><p>Do you get numbness or tingling in the feet? <i>No</i></p><p>Have you been incontinent? <i>No</i></p></div>"
#         }
#       } ]
#     }
#   }, {
#     "fullUrl": "http://localhost:8180/EMIS/FHIR/R4/Composition/f06484de-9fed-4398-9f46-609598c8fef7",
#     "resource": {
#       "resourceType": "Composition",
#       "id": "f06484de-9fed-4398-9f46-609598c8fef7",
#       "identifier": {
#         "use": "usual",
#         "system": "https://tools.ietf.org/html/rfc4122",
#         "value": "c1c732b0-0ac5-45a7-912a-dd5582c066f4",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       },
#       "status": "final",
#       "type": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "823651000000106",
#           "display": "Clinical note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/500029",
#         "type": "Patient"
#       },
#       "encounter": {
#         "reference": "Encounter/f06484de-9fed-4398-9f46-609598c8fef7",
#         "identifier": {
#           "system": "https://emis.com/Id/Consultation/GUID",
#           "value": "f06484de-9fed-4398-9f46-609598c8fef7",
#           "assigner": {
#             "identifier": {
#               "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#               "value": "F83004"
#             }
#           }
#         }
#       },
#       "date": "2024-05-24T00:00:00+00:00",
#       "author": [ {
#         "reference": "Practitioner/d0b035ae-9f7d-4bcd-833b-ec6b19dc12be",
#         "type": "Practitioner",
#         "identifier": {
#           "system": "https://emis.com/Id/Practitioner/GUID",
#           "value": "d0b035ae-9f7d-4bcd-833b-ec6b19dc12be"
#         },
#         "display": "Mr Edward Tanner"
#       } ],
#       "title": "Clinical note",
#       "section": [ {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Hero Health form <i>Fit (sick) note request\nEnables patients to request a medical statement on their fitness to work.\n\nHave you previously had a fit (sick) note about this?\nYes\n\nBriefly describe your illness or medical problem?\nTest condition\n\nReason for fit (sick) note\nUnable to stand comfortably\n\nWhen should the fit (sick) note start?\n24/05/2024\n\nWhen should the fit (sick) note end?\n31/05/2024\n\nCan your employer do anything to help you return to work sooner?\nNO\n\nLast updated: May 24, 2024 10:49</i></p></div>"
#         },
#         "entry": [ {
#           "reference": "Observation/4525c272-88f2-4fae-81d2-83095710dee0",
#           "display": "Hero Health form"
#         } ]
#       } ]
#     }
#   }, {
#     "fullUrl": "http://localhost:8180/EMIS/FHIR/R4/Composition/f98a5d86-c59d-43a4-bdb0-8c1539215e46",
#     "resource": {
#       "resourceType": "Composition",
#       "id": "f98a5d86-c59d-43a4-bdb0-8c1539215e46",
#       "identifier": {
#         "use": "usual",
#         "system": "https://tools.ietf.org/html/rfc4122",
#         "value": "87cec305-316e-431a-86bf-8c063bbc7448",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       },
#       "status": "final",
#       "type": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "823651000000106",
#           "display": "Clinical note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/500029",
#         "type": "Patient"
#       },
#       "encounter": {
#         "reference": "Encounter/f98a5d86-c59d-43a4-bdb0-8c1539215e46",
#         "identifier": {
#           "system": "https://emis.com/Id/Consultation/GUID",
#           "value": "f98a5d86-c59d-43a4-bdb0-8c1539215e46",
#           "assigner": {
#             "identifier": {
#               "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#               "value": "F83004"
#             }
#           }
#         }
#       },
#       "date": "2024-05-14T00:00:00+00:00",
#       "author": [ {
#         "reference": "Practitioner/404d3768-3108-4154-a774-eddf27a4e270",
#         "type": "Practitioner",
#         "identifier": {
#           "system": "https://emis.com/Id/Practitioner/GUID",
#           "value": "404d3768-3108-4154-a774-eddf27a4e270"
#         },
#         "display": "Mr Robert Caldeira"
#       } ],
#       "title": "Clinical note"
#     }
#   }, {
#     "fullUrl": "http://localhost:8180/EMIS/FHIR/R4/Composition/16ed6c7d-62ec-41ea-ad5a-cee3135f489d",
#     "resource": {
#       "resourceType": "Composition",
#       "id": "16ed6c7d-62ec-41ea-ad5a-cee3135f489d",
#       "identifier": {
#         "use": "usual",
#         "system": "https://tools.ietf.org/html/rfc4122",
#         "value": "f49e2012-c237-480d-8d79-96fb85bbaa0b",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       },
#       "status": "final",
#       "type": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "823651000000106",
#           "display": "Clinical note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/500029",
#         "type": "Patient"
#       },
#       "encounter": {
#         "reference": "Encounter/16ed6c7d-62ec-41ea-ad5a-cee3135f489d",
#         "identifier": {
#           "system": "https://emis.com/Id/Consultation/GUID",
#           "value": "16ed6c7d-62ec-41ea-ad5a-cee3135f489d",
#           "assigner": {
#             "identifier": {
#               "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#               "value": "F83004"
#             }
#           }
#         }
#       },
#       "date": "2024-03-07T00:11:29+00:00",
#       "author": [ {
#         "reference": "Practitioner/f9e83fad-2302-44e8-b659-f2941d44cab1",
#         "type": "Practitioner",
#         "identifier": {
#           "system": "https://emis.com/Id/Practitioner/GUID",
#           "value": "f9e83fad-2302-44e8-b659-f2941d44cab1"
#         },
#         "display": "Mr Appointments NEAS"
#       } ],
#       "title": "Clinical note",
#       "section": [ {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Consultation Type <i>Patient requested consultation via practice website.</i></p><p>Virtually consult: health concern <i>Travel vaccination</i></p><p>Notes: <i>\n- type: Triage\n note: sdf\n author: Clinician 2\n\n- type: Disposal\n note: sdfsd\n author: Clinician 2\n</i></p><p>Triage <i>\nTriaged at: 07-03-2024 00:27\nTriaged by: Clinician 2\n\n</i></p><p>Disposal <i>\nDepartment: practice\nAppointment: 28-03-2024 04:33\nAssigned to: Clinician 2\n\nActioned at: 07-03-2024 00:29\nActioned by: Clinician 2\n\n</i></p><p>My Condition <i>Knee pain and problems</i></p><p>foo <i>sdf</i></p></div>"
#         }
#       }, {
#         "title": "Document",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "61150-9",
#             "display": "Subjective Narrative"
#           } ],
#           "text": "Document"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Image (document)</p></div>"
#         },
#         "entry": [ {
#           "reference": "DocumentReference/943d79a8-1830-4308-80da-eedc20d5a792",
#           "type": "DocumentReference"
#         } ]
#       } ]
#     }
#   }, {
#     "fullUrl": "http://localhost:8180/EMIS/FHIR/R4/Composition/a6422619-fc6f-480c-ab86-bac48603a6ee",
#     "resource": {
#       "resourceType": "Composition",
#       "id": "a6422619-fc6f-480c-ab86-bac48603a6ee",
#       "identifier": {
#         "use": "usual",
#         "system": "https://tools.ietf.org/html/rfc4122",
#         "value": "cea81b5f-e2a3-40e1-b91d-089a58802aab",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       },
#       "status": "final",
#       "type": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "823651000000106",
#           "display": "Clinical note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/500029",
#         "type": "Patient"
#       },
#       "encounter": {
#         "reference": "Encounter/a6422619-fc6f-480c-ab86-bac48603a6ee",
#         "identifier": {
#           "system": "https://emis.com/Id/Consultation/GUID",
#           "value": "a6422619-fc6f-480c-ab86-bac48603a6ee",
#           "assigner": {
#             "identifier": {
#               "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#               "value": "F83004"
#             }
#           }
#         }
#       },
#       "date": "2024-02-27T08:55:51+00:00",
#       "author": [ {
#         "reference": "Practitioner/efa90ec0-ca18-4906-bf95-59c712801c88",
#         "type": "Practitioner",
#         "identifier": {
#           "system": "https://emis.com/Id/Practitioner/GUID",
#           "value": "efa90ec0-ca18-4906-bf95-59c712801c88"
#         },
#         "display": "Mr Adam Barnes"
#       } ],
#       "title": "Clinical note",
#       "section": [ {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p> <i>Travel advice eConsult online consultation for Anne Smith, DOB 04-03-2015 submitted on 26-02-2024, 14:14 eConsult reference ID: 81c01501-55bd-4781-9f7a-f1fbf2034889</i></p></div>"
#         }
#       }, {
#         "title": "Document",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "61150-9",
#             "display": "Subjective Narrative"
#           } ],
#           "text": "Document"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Attachment <i>Smith_04_03_2015_81c01501.pdf</i></p></div>"
#         },
#         "entry": [ {
#           "reference": "DocumentReference/9fe6c409-f28a-4a45-9ce9-c09af46adebd",
#           "type": "DocumentReference"
#         } ]
#       }, {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p> <i>Ideas, concerns &amp;amp; expectations \nQ1: Has your child had travel vaccines before? \nA1: Yes\n \nQ2: What travel vaccines have they had and when? \nA2: test test\n \nQ3: Has your child ever had an allergic reaction to a vaccine? \nA3: No\n \nQ4: Do you, or does your child, know what medicine(s) or vaccine(s) they need for this trip? \nA4: No\n \nQ5: Which countries are they travelling to now? \nA5: test test\n \nQ6: What region in the country (countries) are they travelling to? \nA6: test test\n \nQ7: Has your child been to these countries before? \nA7: No\n \nQ8: What are their travel dates (departure and return)? \nA8: test test test\n \nQ9: Why is your child travelling? Please select all that apply. \nA9: Holiday\n \nQ10: Where will your child stay? Please select all that apply. \nA10: City or urban\n \nQ11: Will your child be spending time at an altitude of more than 3000 metres or 9842 feet? \nA11: No\n \nQ12: What is your child's accommodation like? Please select all that apply. \nA12: Hotel, Bed and Breakfast or Apartment\n \nQ13: Is your child covered by travel insurance? \nA13: Yes\n \nQ14: If your child is travelling in Europe, do they have an EHIC card? \nA14: No\n \nQ15: Has your child ever had a blood clot in their leg (DVT) or lung (PE) before? \nA15: No\n \nQ16: Will your child be travelling for more than 5 hours? \nA16: No\n \nQ17: Does your child have HIV? \nA17: No\n \nQ18: Does your child have low immunity because of a medical condition or medication? \nA18: No\n \nQ19: Has your child been circumcised or cut? \nA19: No\n \nQ20: Will your child be travelling with any prescription medicines from their doctor? \nA20: No\n \nQ21: Will your child be travelling with any over-the-counter medicines? \nA21: No\n \nQ22: Will your child be travelling with controlled drugs prescribed by their doctor? \nA22: No\n \nQ23: Is your child allergic to eggs? \nA23: No\n \nQ24: Is your child allergic to latex? \nA24: No\n \nQ25: Do injections make your child feel faint or nervous? \nA25: No\n \nQ26: Have you, or your child, already checked travel health websites (like NaTHNaC Travel Health Pro or Fit For Travel) for advice? \nA26: No\n \nQ27: Do you, or your child, want a &amp;quot;fit to fly&amp;quot; letter from their doctor? \nA27: No\n \nQ28: Do you, or your child, want a letter from their doctor confirming their prescriptions? \nA28: Yes\n \nQ29: Is there anything else you would like to tell us that we have not asked? \nA29: No\n</i></p><p>eConsultation via Online application</p></div>"
#         },
#         "entry": [ {
#           "reference": "Observation/e6b7cb74-9238-49da-9f4e-088385f6e665",
#           "display": "eConsultation via Online application"
#         } ]
#       } ]
#     }
#   }, {
#     "fullUrl": "http://localhost:8180/EMIS/FHIR/R4/Composition/bb3fe9e5-b26d-4e98-b32a-a145f458d0cd",
#     "resource": {
#       "resourceType": "Composition",
#       "id": "bb3fe9e5-b26d-4e98-b32a-a145f458d0cd",
#       "identifier": {
#         "use": "usual",
#         "system": "https://tools.ietf.org/html/rfc4122",
#         "value": "b6d3017c-f842-47d3-84b3-5e77d35c0ab4",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       },
#       "status": "final",
#       "type": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "823651000000106",
#           "display": "Clinical note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/500029",
#         "type": "Patient"
#       },
#       "encounter": {
#         "reference": "Encounter/bb3fe9e5-b26d-4e98-b32a-a145f458d0cd",
#         "identifier": {
#           "system": "https://emis.com/Id/Consultation/GUID",
#           "value": "bb3fe9e5-b26d-4e98-b32a-a145f458d0cd",
#           "assigner": {
#             "identifier": {
#               "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#               "value": "F83004"
#             }
#           }
#         }
#       },
#       "date": "2024-01-31T23:57:11+00:00",
#       "author": [ {
#         "reference": "Practitioner/f9e83fad-2302-44e8-b659-f2941d44cab1",
#         "type": "Practitioner",
#         "identifier": {
#           "system": "https://emis.com/Id/Practitioner/GUID",
#           "value": "f9e83fad-2302-44e8-b659-f2941d44cab1"
#         },
#         "display": "Mr Appointments NEAS"
#       } ],
#       "title": "Clinical note",
#       "section": [ {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Consultation Type <i>Patient requested consultation via practice website.</i></p><p>Virtually consult: health concern <i>Back Pain</i></p><p>Notes: <i>\n- type: Triage\n note: asdsadsad\n author: Clinician 2\n\n- type: Disposal\n note: asdas\n author: Clinician 2\n</i></p><p>Triage <i>\nTriaged at: 07-03-2024 00:41\nTriaged by: Clinician 2\n\n</i></p><p>Disposal <i>\nDepartment: practice\nAppointment: 14-03-2024 03:45\nAssigned to: Clinician 3\n\nActioned at: 07-03-2024 00:42\nActioned by: Clinician 2\n\n</i></p><p>My Condition <i>Unlisted condition</i></p><p>How long have you had these symptoms for? <i>2 weeks</i></p><p>How often do you get headaches and how long do they last? <i>2 hours</i></p><p>What triggers or relieves them? <i>everything</i></p><p>Do you feel nauseous with them? <i>Yes</i></p><p>Do you see flashing lights or have any other visual disturbance when you have a headache or just before? <i>yes</i></p><p>Does the light hurt your eyes when you have a headache? <i>Yes</i></p><p>What prescribed or pharmacy over-the-counter medication have you tried? <i>nothing</i></p><p>Have you seen a doctor for these symptoms before and have you been given a diagnosis? <i>no</i></p><p>Are you on the oral contraceptive pill? <i>No</i></p><p>Do you have a long-term condition or had any significant illnesses in the past? <i>no</i></p><p>How do these symptoms affect your work or daily life? <i>yes</i></p><p>What are you seeking from this consultation? (referral, a prescription or advice) <i>help</i></p></div>"
#         }
#       } ]
#     }
#   }, {
#     "fullUrl": "http://localhost:8180/EMIS/FHIR/R4/Composition/5708e10e-4c10-4b6e-a5fd-b44517b719f6",
#     "resource": {
#       "resourceType": "Composition",
#       "id": "5708e10e-4c10-4b6e-a5fd-b44517b719f6",
#       "identifier": {
#         "use": "usual",
#         "system": "https://tools.ietf.org/html/rfc4122",
#         "value": "52df4494-b615-4981-a047-78d65db42f13",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       },
#       "status": "final",
#       "type": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "823651000000106",
#           "display": "Clinical note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/500029",
#         "type": "Patient"
#       },
#       "encounter": {
#         "reference": "Encounter/5708e10e-4c10-4b6e-a5fd-b44517b719f6",
#         "identifier": {
#           "system": "https://emis.com/Id/Consultation/GUID",
#           "value": "5708e10e-4c10-4b6e-a5fd-b44517b719f6",
#           "assigner": {
#             "identifier": {
#               "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#               "value": "F83004"
#             }
#           }
#         }
#       },
#       "date": "2024-01-19T08:18:24+00:00",
#       "author": [ {
#         "reference": "Practitioner/efa90ec0-ca18-4906-bf95-59c712801c88",
#         "type": "Practitioner",
#         "identifier": {
#           "system": "https://emis.com/Id/Practitioner/GUID",
#           "value": "efa90ec0-ca18-4906-bf95-59c712801c88"
#         },
#         "display": "Mr Adam Barnes"
#       } ],
#       "title": "Clinical note",
#       "section": [ {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p> <i>Travel advice eConsult online consultation for Anne Smith, DOB 04-03-2015 submitted on 18-01-2024, 16:08 eConsult reference ID: b17849ca-8085-4b33-810c-c1e84498ead1</i></p></div>"
#         }
#       }, {
#         "title": "Document",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "61150-9",
#             "display": "Subjective Narrative"
#           } ],
#           "text": "Document"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Attachment <i>Smith_04_03_2015_b17849ca.pdf</i></p></div>"
#         },
#         "entry": [ {
#           "reference": "DocumentReference/72ee2dc3-ccee-4934-a55e-3306f190c91c",
#           "type": "DocumentReference"
#         } ]
#       }, {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p> <i>Ideas, concerns &amp;amp; expectations \nQ1: Has your child had travel vaccines before? \nA1: Yes\n \nQ2: What travel vaccines have they had and when? \nA2: test\n \nQ3: Has your child ever had an allergic reaction to a vaccine? \nA3: No\n \nQ4: Do you, or does your child, know what medicine(s) or vaccine(s) they need for this trip? \nA4: No\n \nQ5: Which countries are they travelling to now? \nA5: test\n \nQ6: What region in the country (countries) are they travelling to? \nA6: test\n \nQ7: Has your child been to these countries before? \nA7: No\n \nQ8: What are their travel dates (departure and return)? \nA8: test\n \nQ9: Why is your child travelling? Please select all that apply. \nA9: Holiday\n \nQ10: Where will your child stay? Please select all that apply. \nA10: Mountains\n \nQ11: Will your child be spending time at an altitude of more than 3000 metres or 9842 feet? \nA11: No\n \nQ12: What is your child's accommodation like? Please select all that apply. \nA12: Hotel, Bed and Breakfast or Apartment\n \nQ13: Is your child covered by travel insurance? \nA13: Yes\n \nQ14: If your child is travelling in Europe, do they have an EHIC card? \nA14: Not applicable\n \nQ15: Has your child ever had a blood clot in their leg (DVT) or lung (PE) before? \nA15: No\n \nQ16: Will your child be travelling for more than 5 hours? \nA16: No\n \nQ17: Does your child have HIV? \nA17: No\n \nQ18: Does your child have low immunity because of a medical condition or medication? \nA18: No\n \nQ19: Has your child been circumcised or cut? \nA19: No\n \nQ20: Will your child be travelling with any prescription medicines from their doctor? \nA20: No\n \nQ21: Will your child be travelling with any over-the-counter medicines? \nA21: No\n \nQ22: Will your child be travelling with controlled drugs prescribed by their doctor? \nA22: No\n \nQ23: Is your child allergic to eggs? \nA23: No\n \nQ24: Is your child allergic to latex? \nA24: No\n \nQ25: Do injections make your child feel faint or nervous? \nA25: No\n \nQ26: Have you, or your child, already checked travel health websites (like NaTHNaC Travel Health Pro or Fit For Travel) for advice? \nA26: No\n \nQ27: Do you, or your child, want a &amp;quot;fit to fly&amp;quot; letter from their doctor? \nA27: No\n \nQ28: Do you, or your child, want a letter from their doctor confirming their prescriptions? \nA28: No\n \nQ29: Is there anything else you would like to tell us that we have not asked? \nA29: No\n</i></p><p>eConsultation via Online application</p></div>"
#         },
#         "entry": [ {
#           "reference": "Observation/bc353769-be7a-4db2-a2ed-c64b82917e6b",
#           "display": "eConsultation via Online application"
#         } ]
#       } ]
#     }
#   }, {
#     "fullUrl": "http://localhost:8180/EMIS/FHIR/R4/Composition/c42221fc-eb20-4b2b-ae1c-e2f531c310c0",
#     "resource": {
#       "resourceType": "Composition",
#       "id": "c42221fc-eb20-4b2b-ae1c-e2f531c310c0",
#       "identifier": {
#         "use": "usual",
#         "system": "https://tools.ietf.org/html/rfc4122",
#         "value": "14164f9e-db84-4a1e-acb1-8b01a303885a",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       },
#       "status": "final",
#       "type": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "823651000000106",
#           "display": "Clinical note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/500029",
#         "type": "Patient"
#       },
#       "encounter": {
#         "reference": "Encounter/c42221fc-eb20-4b2b-ae1c-e2f531c310c0",
#         "identifier": {
#           "system": "https://emis.com/Id/Consultation/GUID",
#           "value": "c42221fc-eb20-4b2b-ae1c-e2f531c310c0",
#           "assigner": {
#             "identifier": {
#               "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#               "value": "F83004"
#             }
#           }
#         }
#       },
#       "date": "2024-01-18T16:14:00+00:00",
#       "author": [ {
#         "reference": "Practitioner/efa90ec0-ca18-4906-bf95-59c712801c88",
#         "type": "Practitioner",
#         "identifier": {
#           "system": "https://emis.com/Id/Practitioner/GUID",
#           "value": "efa90ec0-ca18-4906-bf95-59c712801c88"
#         },
#         "display": "Mr Adam Barnes"
#       } ],
#       "title": "Clinical note",
#       "section": [ {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p> <i>SMS sent to patient (Sent to phone number: 07593985482): Dear Anne Smith\nWould you please send me photos of your [condition]?\nThank you,\nDr barnes\n\nToolbar 2.16.1</i></p></div>"
#         }
#       } ]
#     }
#   }, {
#     "fullUrl": "http://localhost:8180/EMIS/FHIR/R4/Composition/dffba3ad-80b1-47d2-82a2-594e6f8e139d",
#     "resource": {
#       "resourceType": "Composition",
#       "id": "dffba3ad-80b1-47d2-82a2-594e6f8e139d",
#       "identifier": {
#         "use": "usual",
#         "system": "https://tools.ietf.org/html/rfc4122",
#         "value": "5cf3b91b-f977-4bbe-b777-ef41b5ca0b2f",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       },
#       "status": "final",
#       "type": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "823651000000106",
#           "display": "Clinical note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/500029",
#         "type": "Patient"
#       },
#       "encounter": {
#         "reference": "Encounter/dffba3ad-80b1-47d2-82a2-594e6f8e139d",
#         "identifier": {
#           "system": "https://emis.com/Id/Consultation/GUID",
#           "value": "dffba3ad-80b1-47d2-82a2-594e6f8e139d",
#           "assigner": {
#             "identifier": {
#               "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#               "value": "F83004"
#             }
#           }
#         }
#       },
#       "date": "2024-01-18T16:11:00+00:00",
#       "author": [ {
#         "reference": "Practitioner/efa90ec0-ca18-4906-bf95-59c712801c88",
#         "type": "Practitioner",
#         "identifier": {
#           "system": "https://emis.com/Id/Practitioner/GUID",
#           "value": "efa90ec0-ca18-4906-bf95-59c712801c88"
#         },
#         "display": "Mr Adam Barnes"
#       } ],
#       "title": "Clinical note",
#       "section": [ {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p> <i>eConsult Message sent to patient: Thank you for your recent eConsult request.\n----\nVisit https://hnote.me/4MZkn0 to read more information about Hives\n\ntoolbar 2.16.1\nAlso sent the following file: Toolbar Release Testing 2.16.0.pdf</i></p></div>"
#         }
#       } ]
#     }
#   }, {
#     "fullUrl": "http://localhost:8180/EMIS/FHIR/R4/Composition/97a6cdd5-0cfb-41ba-a82c-a82da4308bef",
#     "resource": {
#       "resourceType": "Composition",
#       "id": "97a6cdd5-0cfb-41ba-a82c-a82da4308bef",
#       "identifier": {
#         "use": "usual",
#         "system": "https://tools.ietf.org/html/rfc4122",
#         "value": "61455d10-0007-4458-a6d4-f40646cb537d",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       },
#       "status": "final",
#       "type": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "823651000000106",
#           "display": "Clinical note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/500029",
#         "type": "Patient"
#       },
#       "encounter": {
#         "reference": "Encounter/97a6cdd5-0cfb-41ba-a82c-a82da4308bef",
#         "identifier": {
#           "system": "https://emis.com/Id/Consultation/GUID",
#           "value": "97a6cdd5-0cfb-41ba-a82c-a82da4308bef",
#           "assigner": {
#             "identifier": {
#               "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#               "value": "F83004"
#             }
#           }
#         }
#       },
#       "date": "2024-01-04T23:51:33+00:00",
#       "author": [ {
#         "reference": "Practitioner/f9e83fad-2302-44e8-b659-f2941d44cab1",
#         "type": "Practitioner",
#         "identifier": {
#           "system": "https://emis.com/Id/Practitioner/GUID",
#           "value": "f9e83fad-2302-44e8-b659-f2941d44cab1"
#         },
#         "display": "Mr Appointments NEAS"
#       } ],
#       "title": "Clinical note",
#       "section": [ {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Consultation Type <i>Patient requested consultation via practice website.</i></p><p>Virtually consult: health concern <i>Travel vaccination</i></p><p>Notes: <i>\n- type: Triage\n note: Dispose this\n author: Clinician 2\n\n- type: Triage\n note: sure thing\n author: Allan Love\n\n- type: Disposal\n note: disposed of\n author: Clinician 2\n\n- type: Triage\n note: test another triage note\n author: Clinician 2\n</i></p><p>Triage <i>\nTriaged at: 02-01-2024 00:12\nTriaged by: Clinician 2\n\n</i></p><p>Disposal <i>\nDepartment: practice\nAppointment: 11-01-2024 00:15\nAssigned to: Clinician 2\n\nActioned at: 09-01-2024 00:15\nActioned by: Clinician 2\n\n</i></p><p>My Condition <i>Knee pain and problems</i></p><p>Travel vaccination requirements <i>sdfds</i></p></div>"
#         }
#       }, {
#         "title": "Document",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "61150-9",
#             "display": "Subjective Narrative"
#           } ],
#           "text": "Document"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Image (document)</p></div>"
#         },
#         "entry": [ {
#           "reference": "DocumentReference/007f2ed2-56b5-4937-96c2-f9b585b69de3",
#           "type": "DocumentReference"
#         } ]
#       } ]
#     }
#   }, {
#     "fullUrl": "http://localhost:8180/EMIS/FHIR/R4/Composition/6f0a0985-08a6-4aca-a95d-38636a273322",
#     "resource": {
#       "resourceType": "Composition",
#       "id": "6f0a0985-08a6-4aca-a95d-38636a273322",
#       "identifier": {
#         "use": "usual",
#         "system": "https://tools.ietf.org/html/rfc4122",
#         "value": "56c9b54b-a9ee-45dc-a059-a21c6d23557a",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       },
#       "status": "final",
#       "type": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "823651000000106",
#           "display": "Clinical note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/500029",
#         "type": "Patient"
#       },
#       "encounter": {
#         "reference": "Encounter/6f0a0985-08a6-4aca-a95d-38636a273322",
#         "identifier": {
#           "system": "https://emis.com/Id/Consultation/GUID",
#           "value": "6f0a0985-08a6-4aca-a95d-38636a273322",
#           "assigner": {
#             "identifier": {
#               "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#               "value": "F83004"
#             }
#           }
#         }
#       },
#       "date": "2024-01-04T23:51:33+00:00",
#       "author": [ {
#         "reference": "Practitioner/f9e83fad-2302-44e8-b659-f2941d44cab1",
#         "type": "Practitioner",
#         "identifier": {
#           "system": "https://emis.com/Id/Practitioner/GUID",
#           "value": "f9e83fad-2302-44e8-b659-f2941d44cab1"
#         },
#         "display": "Mr Appointments NEAS"
#       } ],
#       "title": "Clinical note",
#       "section": [ {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Consultation Type <i>Patient requested consultation via practice website.</i></p><p>Virtually consult: health concern <i>Travel vaccination</i></p><p>Notes: <i>\n- type: Triage\n note: Dispose this\n author: Clinician 2\n\n- type: Triage\n note: sure thing\n author: Allan Love\n\n- type: Disposal\n note: disposed of\n author: Clinician 2\n\n- type: Triage\n note: test another triage note\n author: Clinician 2\n</i></p><p>Triage <i>\nTriaged at: 02-01-2024 00:12\nTriaged by: Clinician 2\n\n</i></p><p>Disposal <i>\nDepartment: practice\nAppointment: 09-01-2024 23:19\nAssigned to: Clinician 2\n\nActioned at: 08-01-2024 23:19\nActioned by: Clinician 2\n\n</i></p><p>My Condition <i>Knee pain and problems</i></p><p>Travel vaccination requirements <i>sdfds</i></p></div>"
#         }
#       }, {
#         "title": "Document",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "61150-9",
#             "display": "Subjective Narrative"
#           } ],
#           "text": "Document"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Image (document)</p></div>"
#         },
#         "entry": [ {
#           "reference": "DocumentReference/b76cfb9c-edc6-4cff-b24e-47b311b87942",
#           "type": "DocumentReference"
#         } ]
#       } ]
#     }
#   }, {
#     "fullUrl": "http://localhost:8180/EMIS/FHIR/R4/Composition/3aa564d3-2559-4886-bd2e-37d8e5976de3",
#     "resource": {
#       "resourceType": "Composition",
#       "id": "3aa564d3-2559-4886-bd2e-37d8e5976de3",
#       "identifier": {
#         "use": "usual",
#         "system": "https://tools.ietf.org/html/rfc4122",
#         "value": "e6374489-2f83-41d2-86bb-2dc68ff5dfc6",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       },
#       "status": "final",
#       "type": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "823651000000106",
#           "display": "Clinical note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/500029",
#         "type": "Patient"
#       },
#       "encounter": {
#         "reference": "Encounter/3aa564d3-2559-4886-bd2e-37d8e5976de3",
#         "identifier": {
#           "system": "https://emis.com/Id/Consultation/GUID",
#           "value": "3aa564d3-2559-4886-bd2e-37d8e5976de3",
#           "assigner": {
#             "identifier": {
#               "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#               "value": "F83004"
#             }
#           }
#         }
#       },
#       "date": "2024-01-04T23:51:33+00:00",
#       "author": [ {
#         "reference": "Practitioner/f9e83fad-2302-44e8-b659-f2941d44cab1",
#         "type": "Practitioner",
#         "identifier": {
#           "system": "https://emis.com/Id/Practitioner/GUID",
#           "value": "f9e83fad-2302-44e8-b659-f2941d44cab1"
#         },
#         "display": "Mr Appointments NEAS"
#       } ],
#       "title": "Clinical note",
#       "section": [ {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Consultation Type <i>Patient requested consultation via practice website.</i></p><p>Virtually consult: health concern <i>Travel vaccination</i></p><p>Notes: <i>\n- type: Triage\n note: Dispose this\n author: Clinician 2\n\n- type: Triage\n note: sure thing\n author: Allan Love\n\n- type: Disposal\n note: disposed of\n author: Clinician 2\n\n- type: Triage\n note: test another triage note\n author: Clinician 2\n</i></p><p>Triage <i>\nTriaged at: 02-01-2024 00:12\nTriaged by: Clinician 2\n\n</i></p><p>Disposal <i>\nDepartment: practice\nAppointment: 06-01-2024 00:21\nAssigned to: Clinician 3\n\nActioned at: 05-01-2024 00:21\nActioned by: Clinician 2\n\n</i></p><p>My Condition <i>Knee pain and problems</i></p><p>Travel vaccination requirements <i>sdfds</i></p></div>"
#         }
#       }, {
#         "title": "Document",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "61150-9",
#             "display": "Subjective Narrative"
#           } ],
#           "text": "Document"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Image (document)</p></div>"
#         },
#         "entry": [ {
#           "reference": "DocumentReference/b459b481-e95d-49b0-aa5a-9ee26e4af13a",
#           "type": "DocumentReference"
#         } ]
#       } ]
#     }
#   }, {
#     "fullUrl": "http://localhost:8180/EMIS/FHIR/R4/Composition/a16e80d7-cd78-445d-b077-a90ddfcf2ecf",
#     "resource": {
#       "resourceType": "Composition",
#       "id": "a16e80d7-cd78-445d-b077-a90ddfcf2ecf",
#       "identifier": {
#         "use": "usual",
#         "system": "https://tools.ietf.org/html/rfc4122",
#         "value": "8cf869f6-0107-42d9-9a66-b0e6d16b3daf",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       },
#       "status": "final",
#       "type": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "823651000000106",
#           "display": "Clinical note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/500029",
#         "type": "Patient"
#       },
#       "encounter": {
#         "reference": "Encounter/a16e80d7-cd78-445d-b077-a90ddfcf2ecf",
#         "identifier": {
#           "system": "https://emis.com/Id/Consultation/GUID",
#           "value": "a16e80d7-cd78-445d-b077-a90ddfcf2ecf",
#           "assigner": {
#             "identifier": {
#               "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#               "value": "F83004"
#             }
#           }
#         }
#       },
#       "date": "2023-12-28T23:39:04+00:00",
#       "author": [ {
#         "reference": "Practitioner/f9e83fad-2302-44e8-b659-f2941d44cab1",
#         "type": "Practitioner",
#         "identifier": {
#           "system": "https://emis.com/Id/Practitioner/GUID",
#           "value": "f9e83fad-2302-44e8-b659-f2941d44cab1"
#         },
#         "display": "Mr Appointments NEAS"
#       } ],
#       "title": "Clinical note",
#       "section": [ {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Consultation Type <i>Practitioner sent SMS</i></p><p>SMS Message <i>test</i></p><p>SMS Events <i>sent: 2023-12-28 23:39:07\ndelivered: 2023-12-28 23:44:59\n</i></p></div>"
#         }
#       } ]
#     }
#   }, {
#     "fullUrl": "http://localhost:8180/EMIS/FHIR/R4/Composition/2997b2e8-9752-4e18-8767-3f097295beb2",
#     "resource": {
#       "resourceType": "Composition",
#       "id": "2997b2e8-9752-4e18-8767-3f097295beb2",
#       "identifier": {
#         "use": "usual",
#         "system": "https://tools.ietf.org/html/rfc4122",
#         "value": "199f6597-f0ec-4db4-8008-c2f13b649519",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       },
#       "status": "final",
#       "type": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "823651000000106",
#           "display": "Clinical note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/500029",
#         "type": "Patient"
#       },
#       "encounter": {
#         "reference": "Encounter/2997b2e8-9752-4e18-8767-3f097295beb2",
#         "identifier": {
#           "system": "https://emis.com/Id/Consultation/GUID",
#           "value": "2997b2e8-9752-4e18-8767-3f097295beb2",
#           "assigner": {
#             "identifier": {
#               "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#               "value": "F83004"
#             }
#           }
#         }
#       },
#       "date": "2023-12-11T23:40:38+00:00",
#       "author": [ {
#         "reference": "Practitioner/59df4fa1-707d-4b1d-9d42-c8e942ba1271",
#         "type": "Practitioner",
#         "identifier": {
#           "system": "https://emis.com/Id/Practitioner/GUID",
#           "value": "59df4fa1-707d-4b1d-9d42-c8e942ba1271"
#         },
#         "display": "Dr Dummy One"
#       } ],
#       "title": "Clinical note",
#       "section": [ {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Consultation Type <i>Practitioner completed management plan</i></p><p>Comments and advice <i>test</i></p><p>Important red flags to be aware of <i>watch out</i></p><p>Clinician shorthand notes <i>test shorthand</i></p><p>My Condition <i>Travel vaccination</i></p><p>test <i>qedfw</i></p><p>Screening notes <i>Spoke to patient - urgent care not needed.</i></p></div>"
#         }
#       }, {
#         "title": "Problem",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "10154-3",
#             "display": "Chief complaint Narrative - Reported"
#           } ],
#           "text": "Problem"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Stiff back <i>Stiff back</i></p></div>"
#         },
#         "entry": [ {
#           "reference": "Condition/0ebfc531-71d8-4d74-ac8a-bd6a6b4672eb",
#           "display": "Stiff back"
#         } ]
#       } ]
#     }
#   }, {
#     "fullUrl": "http://localhost:8180/EMIS/FHIR/R4/Composition/b9a2b93a-cda6-4408-8e64-dbff5aacb858",
#     "resource": {
#       "resourceType": "Composition",
#       "id": "b9a2b93a-cda6-4408-8e64-dbff5aacb858",
#       "identifier": {
#         "use": "usual",
#         "system": "https://tools.ietf.org/html/rfc4122",
#         "value": "6dbdba83-659e-4f1b-9125-04d9f2a6ae1f",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       },
#       "status": "final",
#       "type": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "823651000000106",
#           "display": "Clinical note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/500029",
#         "type": "Patient"
#       },
#       "encounter": {
#         "reference": "Encounter/b9a2b93a-cda6-4408-8e64-dbff5aacb858",
#         "identifier": {
#           "system": "https://emis.com/Id/Consultation/GUID",
#           "value": "b9a2b93a-cda6-4408-8e64-dbff5aacb858",
#           "assigner": {
#             "identifier": {
#               "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#               "value": "F83004"
#             }
#           }
#         }
#       },
#       "date": "2023-12-05T11:37:46+00:00",
#       "author": [ {
#         "reference": "Practitioner/f9e83fad-2302-44e8-b659-f2941d44cab1",
#         "type": "Practitioner",
#         "identifier": {
#           "system": "https://emis.com/Id/Practitioner/GUID",
#           "value": "f9e83fad-2302-44e8-b659-f2941d44cab1"
#         },
#         "display": "Mr Appointments NEAS"
#       } ],
#       "title": "Clinical note",
#       "section": [ {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Consultation Type <i>Practitioner sent SMS</i></p><p>SMS Message <i>Dear Ms Smith.\n\nWe have referred you for a blood test, including Lipid Profile investigations. You will find your documents uploaded onto the Virtually Platform. Please note, you will have to fast up to 12 hours before, this means you can only drink water during that time. This is to ensure that we get an accurate result for you. If you have any questions, please feel free to contact us.\n\nClinician 2</i></p><p>SMS Events <i>delivered: 2023-12-05 11:38:16\n</i></p></div>"
#         }
#       } ]
#     }
#   }, {
#     "fullUrl": "http://localhost:8180/EMIS/FHIR/R4/Composition/c44740fc-933f-4037-a784-7c31abe9a52f",
#     "resource": {
#       "resourceType": "Composition",
#       "id": "c44740fc-933f-4037-a784-7c31abe9a52f",
#       "identifier": {
#         "use": "usual",
#         "system": "https://tools.ietf.org/html/rfc4122",
#         "value": "7a593068-b4d4-4fab-b65a-f0fb0a1e9e89",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       },
#       "status": "final",
#       "type": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "823651000000106",
#           "display": "Clinical note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/500029",
#         "type": "Patient"
#       },
#       "encounter": {
#         "reference": "Encounter/c44740fc-933f-4037-a784-7c31abe9a52f",
#         "identifier": {
#           "system": "https://emis.com/Id/Consultation/GUID",
#           "value": "c44740fc-933f-4037-a784-7c31abe9a52f",
#           "assigner": {
#             "identifier": {
#               "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#               "value": "F83004"
#             }
#           }
#         }
#       },
#       "date": "2023-12-04T10:47:35+00:00",
#       "author": [ {
#         "reference": "Practitioner/f9e83fad-2302-44e8-b659-f2941d44cab1",
#         "type": "Practitioner",
#         "identifier": {
#           "system": "https://emis.com/Id/Practitioner/GUID",
#           "value": "f9e83fad-2302-44e8-b659-f2941d44cab1"
#         },
#         "display": "Mr Appointments NEAS"
#       } ],
#       "title": "Clinical note",
#       "section": [ {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Consultation Type <i>Practitioner sent SMS</i></p><p>SMS Message <i>Dear Ms Smith.\n\nThis is to confirm that your blood test form and the hospital letter has been uploaded under your documents tab in Virtually. To download the form, please login via https://virtually.healthcare/\n\nIf you experience any problems downloading the document, please submit a helpdesk ticket.\n\nClinician 2</i></p><p>SMS Events <i>delivered: 2023-12-04 10:48:29\n</i></p></div>"
#         }
#       } ]
#     }
#   }, {
#     "fullUrl": "http://localhost:8180/EMIS/FHIR/R4/Composition/4a53c679-5ea6-44b9-80cc-e7bdb6051793",
#     "resource": {
#       "resourceType": "Composition",
#       "id": "4a53c679-5ea6-44b9-80cc-e7bdb6051793",
#       "identifier": {
#         "use": "usual",
#         "system": "https://tools.ietf.org/html/rfc4122",
#         "value": "cd1d50f8-5e66-48c7-a27d-fadf6d5ff7be",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       },
#       "status": "final",
#       "type": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "823651000000106",
#           "display": "Clinical note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/500029",
#         "type": "Patient"
#       },
#       "encounter": {
#         "reference": "Encounter/4a53c679-5ea6-44b9-80cc-e7bdb6051793",
#         "identifier": {
#           "system": "https://emis.com/Id/Consultation/GUID",
#           "value": "4a53c679-5ea6-44b9-80cc-e7bdb6051793",
#           "assigner": {
#             "identifier": {
#               "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#               "value": "F83004"
#             }
#           }
#         }
#       },
#       "date": "2023-12-04T10:46:02+00:00",
#       "author": [ {
#         "reference": "Practitioner/f9e83fad-2302-44e8-b659-f2941d44cab1",
#         "type": "Practitioner",
#         "identifier": {
#           "system": "https://emis.com/Id/Practitioner/GUID",
#           "value": "f9e83fad-2302-44e8-b659-f2941d44cab1"
#         },
#         "display": "Mr Appointments NEAS"
#       } ],
#       "title": "Clinical note",
#       "section": [ {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Consultation Type <i>Practitioner sent SMS</i></p><p>SMS Message <i>Dear Ms Smith.\n\nThis is to confirm that your blood test form and the hospital letter has been uploaded under your documents tab in Virtually. To download the form, please login via https://virtually.healthcare/\n\nIf you experience any problems downloading the document, please submit a helpdesk ticket.\n\nClinician 2</i></p><p>SMS Events <i>sent: 2023-12-04 10:46:05\ndelivered: 2023-12-04 10:46:08\n</i></p></div>"
#         }
#       } ]
#     }
#   }, {
#     "fullUrl": "http://localhost:8180/EMIS/FHIR/R4/Composition/f7f561e9-2e9f-4857-8457-06ef60c3fdd1",
#     "resource": {
#       "resourceType": "Composition",
#       "id": "f7f561e9-2e9f-4857-8457-06ef60c3fdd1",
#       "identifier": {
#         "use": "usual",
#         "system": "https://tools.ietf.org/html/rfc4122",
#         "value": "ff85496d-b765-4b1b-bdd0-f131a5419e86",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       },
#       "status": "final",
#       "type": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "823651000000106",
#           "display": "Clinical note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/500029",
#         "type": "Patient"
#       },
#       "encounter": {
#         "reference": "Encounter/f7f561e9-2e9f-4857-8457-06ef60c3fdd1",
#         "identifier": {
#           "system": "https://emis.com/Id/Consultation/GUID",
#           "value": "f7f561e9-2e9f-4857-8457-06ef60c3fdd1",
#           "assigner": {
#             "identifier": {
#               "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#               "value": "F83004"
#             }
#           }
#         }
#       },
#       "date": "2023-10-30T11:24:17+00:00",
#       "author": [ {
#         "reference": "Practitioner/f9e83fad-2302-44e8-b659-f2941d44cab1",
#         "type": "Practitioner",
#         "identifier": {
#           "system": "https://emis.com/Id/Practitioner/GUID",
#           "value": "f9e83fad-2302-44e8-b659-f2941d44cab1"
#         },
#         "display": "Mr Appointments NEAS"
#       } ],
#       "title": "Clinical note",
#       "section": [ {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Consultation Type <i>Practitioner sent SMS</i></p><p>SMS Message <i>Dear Ms Smith.\n\nDr. Clinician 2, has requested that you upload images. Please click the link to complete the form.\n\nhttps://dev.virtually.healthcare.eu.ngrok.io/short-url/XE2Stx</i></p><p>SMS Events <i>sent: 2023-10-30 11:24:20\ndelivered: 2023-10-30 11:24:22\n</i></p></div>"
#         }
#       } ]
#     }
#   }, {
#     "fullUrl": "http://localhost:8180/EMIS/FHIR/R4/Composition/69fb0b0c-74b8-4438-98f8-eacf1f40a5b5",
#     "resource": {
#       "resourceType": "Composition",
#       "id": "69fb0b0c-74b8-4438-98f8-eacf1f40a5b5",
#       "identifier": {
#         "use": "usual",
#         "system": "https://tools.ietf.org/html/rfc4122",
#         "value": "77473eb9-a7de-4acc-9c17-67b41c2c0e7a",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       },
#       "status": "final",
#       "type": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "823651000000106",
#           "display": "Clinical note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/500029",
#         "type": "Patient"
#       },
#       "encounter": {
#         "reference": "Encounter/69fb0b0c-74b8-4438-98f8-eacf1f40a5b5",
#         "identifier": {
#           "system": "https://emis.com/Id/Consultation/GUID",
#           "value": "69fb0b0c-74b8-4438-98f8-eacf1f40a5b5",
#           "assigner": {
#             "identifier": {
#               "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#               "value": "F83004"
#             }
#           }
#         }
#       },
#       "date": "2023-10-30T11:23:29+00:00",
#       "author": [ {
#         "reference": "Practitioner/f9e83fad-2302-44e8-b659-f2941d44cab1",
#         "type": "Practitioner",
#         "identifier": {
#           "system": "https://emis.com/Id/Practitioner/GUID",
#           "value": "f9e83fad-2302-44e8-b659-f2941d44cab1"
#         },
#         "display": "Mr Appointments NEAS"
#       } ],
#       "title": "Clinical note",
#       "section": [ {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Consultation Type <i>Practitioner sent SMS</i></p><p>SMS Message <i>Dear Ms Smith.\n\nDr. Clinician 2, has requested that you complete a questionnaire regarding your current symptoms. Please click the link to complete the form.\n\nhttps://dev.virtually.healthcare.eu.ngrok.io/short-url/XQCioT</i></p><p>SMS Events <i>sent: 2023-10-30 11:23:37\ndelivered: 2023-10-30 11:23:38\n</i></p></div>"
#         }
#       } ]
#     }
#   }, {
#     "fullUrl": "http://localhost:8180/EMIS/FHIR/R4/Composition/c9910a9b-7527-4a51-b4e0-8cbf8e9a543b",
#     "resource": {
#       "resourceType": "Composition",
#       "id": "c9910a9b-7527-4a51-b4e0-8cbf8e9a543b",
#       "identifier": {
#         "use": "usual",
#         "system": "https://tools.ietf.org/html/rfc4122",
#         "value": "f617f7a7-1dd8-45f6-9c0e-b00c11c677eb",
#         "assigner": {
#           "identifier": {
#             "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#             "value": "F83004"
#           }
#         }
#       },
#       "status": "final",
#       "type": {
#         "coding": [ {
#           "system": "http://snomed.info/sct",
#           "code": "823651000000106",
#           "display": "Clinical note"
#         } ]
#       },
#       "subject": {
#         "reference": "Patient/500029",
#         "type": "Patient"
#       },
#       "encounter": {
#         "reference": "Encounter/c9910a9b-7527-4a51-b4e0-8cbf8e9a543b",
#         "identifier": {
#           "system": "https://emis.com/Id/Consultation/GUID",
#           "value": "c9910a9b-7527-4a51-b4e0-8cbf8e9a543b",
#           "assigner": {
#             "identifier": {
#               "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#               "value": "F83004"
#             }
#           }
#         }
#       },
#       "date": "2023-10-30T11:14:45+00:00",
#       "author": [ {
#         "reference": "Practitioner/f9e83fad-2302-44e8-b659-f2941d44cab1",
#         "type": "Practitioner",
#         "identifier": {
#           "system": "https://emis.com/Id/Practitioner/GUID",
#           "value": "f9e83fad-2302-44e8-b659-f2941d44cab1"
#         },
#         "display": "Mr Appointments NEAS"
#       } ],
#       "title": "Clinical note",
#       "section": [ {
#         "title": "Comment",
#         "code": {
#           "coding": [ {
#             "system": "http://loinc.org",
#             "code": "48767-8",
#             "display": "Annotation comment [Interpretation] Narrative"
#           } ],
#           "text": "Comment"
#         },
#         "text": {
#           "status": "generated",
#           "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p>Consultation Type <i>Practitioner sent SMS</i></p><p>SMS Message <i>Dear Ms Smith.\n\nDr. Clinician 2, has requested that you provide information regarding your current symptoms. Please click the link to complete the form.\n\nhttps://dev.virtually.healthcare.eu.ngrok.io/short-url/kLzYn1</i></p><p>SMS Events <i>sent: 2023-10-30 11:14:48\ndelivered: 2023-10-30 11:14:52\n</i></p></div>"
#         }
#       } ]
#     }
#   } ]
# }
# Have composition
# DUPLICATE SHOULD GRACEFULLY FINISH
# Have composition
# Have composition
# Have composition
# Have composition
# Have composition
# Have composition
# Have composition
# Have composition
# Have composition
# Have composition
# Have composition
# Have composition
# Have composition
# Have composition
# Have composition
# Have composition
# Have composition
# Have composition
# Have composition

# %% [markdown]
# ### FHIR Validation (Testing)
#
# TODO FHIR Validate - This takes time to run. So only provide a basic example.
#
# `POST {baseUrl}/ESB/R4/$validate`
#
# This checks the FHIR payload is valid against [Virtually Healthcare Implementation Guide](https://virtually-healthcare.github.io/R4/)

# %%
esbFHIRUrl = "http://localhost:8181/ESB/R4"
headersESB = {"Content-Type": "application/fhir+json",
               "ODS_CODE": "F83004"}

for record in FHIRMessages:
    # begin fix the bundle
    resource = json.loads(record['response'])

    #print(json.dumps(resource))
    responseValidate = requests.post(esbFHIRUrl + '/$validate', json.dumps(resource), headers=headersESB)
    print("======= Response from FHIR Validation ========")
    print("Status code = " + str(responseValidate.status_code))
    operationOutcome = json.loads(responseValidate.text)
    failed = False

    if 'issue' in operationOutcome:
        print("======= Error ========")
        for issue in operationOutcome['issue']:
            if issue['severity'] == 'error':
                ignore = False
                if 'details' in issue:
                    if '307321000000107' in issue['details']['text']:
                        ignore = True
                if not ignore:
                    failed = True
                    if 'details' in issue:
                        print("Issue: " + issue['details']['text'] + ' [' + issue['severity'] + ']')
                    if 'diagnostics' in issue:
                        print("Issue: " + issue['diagnostics'] + ' [' + issue['severity'] + ']')
                    if 'expression' in issue:
                        print(issue['expression'])
                    print('')
        print("======= Warning ========")
        for issue in operationOutcome['issue']:
            if issue['severity'] == 'warning':
                if 'details' in issue:
                    print("Issue: " + issue['details']['text'] + ' [' + issue['severity'] + ']')
                if 'diagnostics' in issue:
                    print("Issue: " + issue['diagnostics'] + ' [' + issue['severity'] + ']')
                if 'expression' in issue:
                    print(issue['expression'])
                print('')

    if failed:
        print("FAILED Validation")
         #record['task']['status'] = 'failed'
         #response = requests.put(cdrFHIRUrl + '/Task/' + task['id'],json.dumps(task),headers=headersCDR)
        #print(response.text)
        #break
# Out:
# ======= Response from FHIR Validation ========
# Status code = 200
# ======= Error ========
# ======= Warning ========
# Issue: None of the codings provided are in the value set 'IdentifierType' (http://hl7.org/fhir/ValueSet/identifier-type|4.0.1), and a coding should come from this value set unless it has no suitable code (note that the validator cannot judge what is suitable) (codes = http://terminology.hl7.org/CodeSystem/v2-0203#NH) [warning]
# ['Bundle.entry[2].resource/*Patient/2cdce27e-9398-4367-8719-d872710e8e63*/.identifier[1].type']
#
# Issue: None of the codings provided are in the value set 'ServiceDeliveryLocationRoleType' (http://terminology.hl7.org/ValueSet/v3-ServiceDeliveryLocationRoleType|3.0.0), and a coding should come from this value set unless it has no suitable code (note that the validator cannot judge what is suitable) (codes = http://snomed.info/sct#307321000000107) [warning]
# ['Bundle.entry[3].resource/*Location/daabb4e8-dab2-4237-a957-122fe83e62a3*/.type[0]']
#
# Issue: ValueSet 'http://snomed.info/sct/900000000000207008?fhir_vs=ecl/%3C404684003' not found [warning]
# ['Bundle.entry[5].resource/*QuestionnaireResponse/238c8ff7-f5d6-47be-a2ca-218c8732d68d*/.item[1].item[0].item[0].answer[0]']
#
# Issue: ValueSet 'http://snomed.info/sct/900000000000207008?fhir_vs=ecl/%3C404684003' not found [warning]
# ['Bundle.entry[5].resource.item[1].item[0].item[0].answer[0]']

# %% [markdown]
# ### Convert to EMISOpen

# %%
emisFHIRUrl = "http://localhost:8180/EMIS/FHIR/R4"
headersEMIS = {"Content-Type": "application/fhir+json",
               "ODS_CODE": "F83004"}

EMISOpenRecords = []
for record in FHIRMessages:
    responseEMISTransform = requests.post(emisFHIRUrl + '/Bundle/$transform-EMISOpen', record['response'], headers=headersEMIS )
    print("======= Response from transform to EMIS Open ========")
    print(responseEMISTransform.text)
    EMISOpenRecords.append({
        "response" : responseEMISTransform.text,
        "task": record['task']
    })
# Out:
# ======= Response from transform to EMIS Open ========
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <MedicalRecord PatientID="500837" xmlns="http://www.e-mis.com/emisopen/MedicalRecord">
#     <ConsultationList>
#         <Consultation>
#             <GUID>d3aa0f25-6ceb-4baf-bb4f-8f53170c5231</GUID>
#             <AssignedDate>20/05/2025 04:00:00</AssignedDate>
#             <UserID>
#                 <RefID>2</RefID>
#             </UserID>
#             <LocationTypeID>
#                 <RefID>1</RefID>
#             </LocationTypeID>
#             <OriginalAuthor>
#                 <User>
#                     <RefID>2</RefID>
#                 </User>
#             </OriginalAuthor>
#             <ElementList>
#                 <ConsultationElement>
#                     <RefID>1</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>368ad6e7-4975-4a3d-97af-11a736816621</GUID>
#                         <AssignedDate>19/05/2025 15:43:05</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Consultation Type</DisplayTerm>
#                         <DescriptiveText>Practitioner completed management plan</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>3</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>566fe967-2c3a-46cb-8991-2d4b126e219f</GUID>
#                         <AssignedDate>19/05/2025 15:43:05</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Comments and advice</DisplayTerm>
#                         <DescriptiveText>This is to see if writing back works</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>4</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>56b9feaf-89fd-4449-9a91-e9e53bcfb01a</GUID>
#                         <AssignedDate>19/05/2025 15:43:05</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Important red flags to be aware of</DisplayTerm>
#                         <DescriptiveText>let me see the flags</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>5</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>4979ab4b-b9f8-44f1-933a-8d36cbfb33ee</GUID>
#                         <AssignedDate>19/05/2025 15:43:05</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>My Condition</DisplayTerm>
#                         <DescriptiveText>Back Pain</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>6</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>f10f9083-533e-461a-ac19-208575082e23</GUID>
#                         <AssignedDate>19/05/2025 15:43:05</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Radio Group</DisplayTerm>
#                         <DescriptiveText>Option 2 (med)</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>7</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>9bdbd182-2197-418b-800a-59074aa0b06a</GUID>
#                         <AssignedDate>19/05/2025 15:43:05</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Select</DisplayTerm>
#                         <DescriptiveText>Option 3 (high)</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>8</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>1d4b6e02-de88-4f1d-aad3-5630ba68b44a</GUID>
#                         <AssignedDate>19/05/2025 15:43:05</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Text Field</DisplayTerm>
#                         <DescriptiveText>some text here</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>9</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>73d8c644-21d2-4412-a95f-1066c37788dc</GUID>
#                         <AssignedDate>19/05/2025 15:43:05</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Text Area</DisplayTerm>
#                         <DescriptiveText>Possimus aperiam pl</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>10</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>caafca8f-c597-420b-ad72-78b76e31fd69</GUID>
#                         <AssignedDate>19/05/2025 15:43:05</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Checkbox Group</DisplayTerm>
#                         <DescriptiveText>Option 1, Option 3</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>11</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>9ded36d8-a275-43b9-8d14-946682f849b2</GUID>
#                         <AssignedDate>19/05/2025 15:43:05</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Date Field</DisplayTerm>
#                         <DescriptiveText>2025-05-09</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>12</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>e8ade70e-5340-43b7-b594-664b5cc52951</GUID>
#                         <AssignedDate>19/05/2025 15:43:05</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Number</DisplayTerm>
#                         <DescriptiveText>121</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>14</RefID>
#                     <Header>
#                         <Term>Problem List</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>a487cd9f-5769-4f4d-b6a5-c685c966aa3b</GUID>
#                         <AssignedDate>19/05/2025 15:43:05</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>UTI - Urinary tract infection</DisplayTerm>
#                         <DescriptiveText>UTI - Urinary tract infection</DescriptiveText>
#                         <Code>
#                             <Value>68566005</Value>
#                             <Scheme>SNOMED</Scheme>
#                             <Term>UTI - Urinary tract infection</Term>
#                         </Code>
#                         <TermID>
#                             <Value>68566005</Value>
#                             <Scheme>SNOMED</Scheme>
#                             <Term>UTI - Urinary tract infection</Term>
#                         </TermID>
#                         <Problem>
#                             <ProblemStatus>1</ProblemStatus>
#                             <ProblemType>1</ProblemType>
#                             <ExpectedDuration>84</ExpectedDuration>
#                         </Problem>
#                         <Abnormal>0</Abnormal>
#                         <EventType>1</EventType>
#                     </Event>
#                 </ConsultationElement>
#             </ElementList>
#         </Consultation>
#     </ConsultationList>
#     <PeopleList>
#         <Person>
#             <DBID>999999</DBID>
#             <RefID>999</RefID>
#             <GUID>2ec24d6b-2653-4f6a-ad83-d51639329f91</GUID>
#             <Title>Ms</Title>
#             <FirstNames>Data</FirstNames>
#             <LastName>Patient-Entered</LastName>
#         </Person>
#         <Person>
#             <RefID>2</RefID>
#             <GUID>45ce9a3d-2562-47f5-9dbf-91dff0485f5d</GUID>
#             <Title>Ms</Title>
#             <FirstNames>Embargo</FirstNames>
#             <LastName>RapidHealth</LastName>
#         </Person>
#     </PeopleList>
#     <LocationTypeList>
#         <LocationType>
#             <RefID>1</RefID>
#             <GUID>bc5eb960-91c0-41f9-8ecf-f1f666f5a378</GUID>
#             <Description>Virtually video</Description>
#         </LocationType>
#     </LocationTypeList>
# </MedicalRecord>
#
# ======= Response from transform to EMIS Open ========
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <MedicalRecord PatientID="500029" xmlns="http://www.e-mis.com/emisopen/MedicalRecord">
#     <ConsultationList>
#         <Consultation>
#             <GUID>f7ff9fd2-11f7-4a4e-9d84-dfccc669c7e9</GUID>
#             <AssignedDate>17/03/2025 22:42:41</AssignedDate>
#             <UserID>
#                 <RefID>2</RefID>
#             </UserID>
#             <LocationTypeID>
#                 <RefID>1</RefID>
#             </LocationTypeID>
#             <OriginalAuthor>
#                 <User>
#                     <RefID>2</RefID>
#                 </User>
#             </OriginalAuthor>
#             <ElementList>
#                 <ConsultationElement>
#                     <RefID>1</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>ce0a64b6-aa72-4507-b758-924d9536242d</GUID>
#                         <AssignedDate>17/03/2025 22:42:41</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Consultation Type</DisplayTerm>
#                         <DescriptiveText>Patient requested consultation via practice website.</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>3</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>ea713134-73d2-4a5d-afcb-81adf3f9a11c</GUID>
#                         <AssignedDate>17/03/2025 22:42:41</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Virtually consult: health concern</DisplayTerm>
#                         <DescriptiveText>Back Pain</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>4</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>dda1ab2d-7f74-45c1-beed-a5a24b45a3ac</GUID>
#                         <AssignedDate>17/03/2025 22:42:41</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Submitted by:</DisplayTerm>
#                         <DescriptiveText>Clinician 1</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>5</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>5ad7c5df-1b59-4aca-b1ef-9eb6fb7cd889</GUID>
#                         <AssignedDate>17/03/2025 22:42:41</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Submitted at:</DisplayTerm>
#                         <DescriptiveText>2025-03-17 22:42:41</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>6</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>2f4530da-a4ce-4924-8a78-6d7eee6ceac4</GUID>
#                         <AssignedDate>17/03/2025 22:42:41</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Notes:</DisplayTerm>
#                         <DescriptiveText>
# - type: Triage
#  note: dfgdfg
#  author: Clinician 1
# </DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>7</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>26aa51c1-8b27-48e8-bd26-d25efc1b056d</GUID>
#                         <AssignedDate>17/03/2025 22:42:41</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Triage</DisplayTerm>
#                         <DescriptiveText>
# Triaged at: 17-03-2025 22:45
# Triaged by: Clinician 1
#
# </DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>8</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>80bbb896-56df-4882-b238-1926aff7ec16</GUID>
#                         <AssignedDate>17/03/2025 22:42:41</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Disposal</DisplayTerm>
#                         <DescriptiveText>
# Department: practice
# Appointment: 18-03-2025 22:45
# Assigned to: Clinician 2
#
# Actioned at: 17-03-2025 22:46
# Actioned by: Clinician 1
#
# </DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>9</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>a15e11b0-c95b-418f-92fa-9bcf62d751c1</GUID>
#                         <AssignedDate>17/03/2025 22:42:41</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>My Condition</DisplayTerm>
#                         <DescriptiveText>Unlisted condition</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>10</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>784ea022-2041-4fba-bf3a-afc2db35b798</GUID>
#                         <AssignedDate>17/03/2025 22:42:41</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>How long have you had this episode?</DisplayTerm>
#                         <DescriptiveText>1</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>11</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>080cc84b-e9c0-4d65-a781-78de5244c576</GUID>
#                         <AssignedDate>17/03/2025 22:42:41</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Have you had it before? If so when was the last episode?</DisplayTerm>
#                         <DescriptiveText>2</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>12</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>c26f48f9-3629-4204-b76a-e5a02be79264</GUID>
#                         <AssignedDate>17/03/2025 22:42:41</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>When do you recall first having back pain?</DisplayTerm>
#                         <DescriptiveText>dfg</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>13</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>848e1d9a-228a-4ce6-af83-b0bf07cf28cd</GUID>
#                         <AssignedDate>17/03/2025 22:42:41</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Does it affect your work, sleep, daily activities, walking or recreation?</DisplayTerm>
#                         <DescriptiveText>No</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>14</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>5c04f7ba-c714-4e01-9c02-bbf671c6d5da</GUID>
#                         <AssignedDate>17/03/2025 22:42:41</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>What part of the back is the pain in?</DisplayTerm>
#                         <DescriptiveText>dfg</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>15</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>96d19662-201d-4c01-b74c-89f17c378362</GUID>
#                         <AssignedDate>17/03/2025 22:42:41</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Does it go down either leg? If so how far down?</DisplayTerm>
#                         <DescriptiveText>dfg</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>16</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>322af790-18e0-4902-a353-ab476e48fd0d</GUID>
#                         <AssignedDate>17/03/2025 22:42:41</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Do you get numbness or tingling in the feet?</DisplayTerm>
#                         <DescriptiveText>No</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#                 <ConsultationElement>
#                     <RefID>17</RefID>
#                     <Header>
#                         <Term>Comment</Term>
#                     </Header>
#                     <Event>
#                         <RefID>1</RefID>
#                         <GUID>e0172782-23cf-4af1-9e2d-ea88d765108a</GUID>
#                         <AssignedDate>17/03/2025 22:42:41</AssignedDate>
#                         <AuthorID>
#                             <RefID>2</RefID>
#                         </AuthorID>
#                         <OriginalAuthor>
#                             <User>
#                                 <RefID>2</RefID>
#                             </User>
#                         </OriginalAuthor>
#                         <DisplayTerm>Have you been incontinent?</DisplayTerm>
#                         <DescriptiveText>No</DescriptiveText>
#                     </Event>
#                 </ConsultationElement>
#             </ElementList>
#         </Consultation>
#     </ConsultationList>
#     <PeopleList>
#         <Person>
#             <DBID>999999</DBID>
#             <RefID>999</RefID>
#             <GUID>2ec24d6b-2653-4f6a-ad83-d51639329f91</GUID>
#             <Title>Ms</Title>
#             <FirstNames>Data</FirstNames>
#             <LastName>Patient-Entered</LastName>
#         </Person>
#         <Person>
#             <RefID>2</RefID>
#             <GUID>f9e83fad-2302-44e8-b659-f2941d44cab1</GUID>
#             <Title></Title>
#             <FirstNames></FirstNames>
#         </Person>
#     </PeopleList>
#     <LocationTypeList>
#         <LocationType>
#             <RefID>1</RefID>
#             <GUID>c25fe93c-70df-4618-9aed-548bee0229e0</GUID>
#             <Description>Virtually adhoc</Description>
#         </LocationType>
#     </LocationTypeList>
# </MedicalRecord>

# %% [markdown]
# ### Send Consultation Note
#
# Send to EMISOpen formated interactions to EMIS IM1 Transaction API.

# %%
sendResponses = []
for EMISOpen in EMISOpenRecords:

    headersEMIS = {"Content-Type": "application/fhir+json",
               "ODS_CODE": "F83004"}
    body = {
        "resourceType": "Parameters",
        "parameter" : [ {
            "name" : "EMISOpen",
            "valueString": EMISOpen['response']  }]
    }

    responseEMISSend = requests.post(emisFHIRUrl + '/$send-EMISOpen', json.dumps(body), headers=headersEMIS )
    print("======= Send to EMIS Open ========")
    print(responseEMISSend.text)
    sendResponses.append({
        "response" : responseEMISSend.text,
        "task": EMISOpen['task']
    }
)
# Out:
# ======= Send to EMIS Open ========
# {
#   "resourceType": "OperationOutcome",
#   "issue": [ {
#     "severity": "error",
#     "code": "exception",
#     "diagnostics": "HTTP operation failed invoking http://172.31.22.225/emis/MedicalRecord/500837? with statusCode: 400"
#   } ]
# }
# ======= Send to EMIS Open ========
# {
#   "resourceType": "OperationOutcome",
#   "issue": [ {
#     "severity": "information",
#     "code": "informational"
#   } ]
# }

# %% [markdown]
# ### Update Send Consulation Note workflow status
#
# Update Task to say it is completed or failed

# %%
headersCDR = {"Content-Type": "application/fhir+json", "Accept": "application/fhir+json"}

for sendResponse in sendResponses:
    task = sendResponse['task']
    task['status'] = 'completed'
    response = requests.put(cdrFHIRUrl + '/Task/' + task['id'],json.dumps(task),headers=headersCDR)
    print(response.text)
# Out:
# {
#   "resourceType": "Task",
#   "id": "8b12d352-b2dc-4647-a544-ea2ed30011e1",
#   "meta": {
#     "versionId": "379",
#     "lastUpdated": "2025-06-26T11:45:43.981Z"
#   },
#   "identifier": [ {
#     "system": "https://fhir.virtually.healthcare/Id/Task",
#     "value": "537fd315-8a60-4c02-a96e-473bd04a138d"
#   } ],
#   "status": "completed",
#   "intent": "order",
#   "priority": "routine",
#   "code": {
#     "coding": [ {
#       "system": "http://fhir.virtuallyhealthcare.co.uk/CodeSystem/tasks",
#       "code": "WRITEBACK",
#       "display": "Consultation Write Back"
#     } ]
#   },
#   "focus": {
#     "reference": "Encounter/3493d264-ab4e-4794-9622-555ed16b75aa",
#     "identifier": {
#       "system": "https://fhir.virtually.healthcare/Id/Encounter",
#       "value": "d3aa0f25-6ceb-4baf-bb4f-8f53170c5231"
#     }
#   },
#   "for": {
#     "reference": "Patient/2cdce27e-9398-4367-8719-d872710e8e63"
#   },
#   "authoredOn": "2025-05-19T15:43:08+00:00",
#   "owner": {
#     "reference": "Organization/61a55cac-08d5-4cf8-a4d5-581f50962a82",
#     "identifier": {
#       "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#       "value": "F83004"
#     }
#   },
#   "note": [ {
#     "time": "2025-05-19T15:44:09+00:00",
#     "text": "Consultation written back to EPR system"
#   }, {
#     "time": "2025-06-23T06:25:22+00:00",
#     "text": "Moved from failure list to rejected"
#   }, {
#     "time": "2025-06-23T06:55:56+00:00",
#     "text": "Consultation written back to EPR system"
#   } ],
#   "input": [ {
#     "type": {
#       "text": "ResourceReference"
#     },
#     "valueReference": {
#       "reference": "QuestionnaireResponse/238c8ff7-f5d6-47be-a2ca-218c8732d68d"
#     }
#   } ],
#   "output": [ {
#     "type": {
#       "coding": [ {
#         "code": "WRITEBACK"
#       } ]
#     },
#     "valueString": "\n<MedicalRecord PatientID=\"500837\" xmlns=\"http://www.e-mis.com/emisopen/MedicalRecord\">\n    <ConsultationList>\n        <Consultation>\n            <GUID>d3aa0f25-6ceb-4baf-bb4f-8f53170c5231</GUID>\n            <AssignedDate>19/05/2025 15:43:05</AssignedDate>\n            <UserID>\n                <RefID>5885</RefID>\n            </UserID>\n            <LocationTypeID>\n                <RefID>307321000000107</RefID>\n            </LocationTypeID>\n            <OriginalAuthor>\n                <User>\n                    <RefID>5885</RefID>\n                </User>\n            </OriginalAuthor>\n            <ElementList>\n                <ConsultationElement>\n                    <RefID>1</RefID>\n                    <Header>\n                        <Term>Comment</Term>\n                    </Header>\n                    <Event>\n                        <RefID>1</RefID>\n                        <GUID>ae35314d-332f-4cda-b3ff-36b30497f73d</GUID>\n                        <AssignedDate>19/05/2025 15:43:05</AssignedDate>\n                        <AuthorID>\n                            <RefID>5885</RefID>\n                        </AuthorID>\n                        <OriginalAuthor>\n                            <User>\n                                <RefID>5885</RefID>\n                            </User>\n                        </OriginalAuthor>\n                        <DisplayTerm>Consultation Type</DisplayTerm>\n                        <DescriptiveText>Practitioner completed management plan</DescriptiveText>\n                    </Event>\n                </ConsultationElement>\n                <ConsultationElement>\n                    <RefID>2</RefID>\n                    <Header>\n                        <Term>Comment</Term>\n                    </Header>\n                    <Event>\n                        <RefID>1</RefID>\n                        <GUID>b55bd381-7846-4890-bde7-bea7a27e6948</GUID>\n                        <AssignedDate>19/05/2025 15:43:05</AssignedDate>\n                        <AuthorID>\n                            <RefID>5885</RefID>\n                        </AuthorID>\n                        <OriginalAuthor>\n                            <User>\n                                <RefID>5885</RefID>\n                            </User>\n                        </OriginalAuthor>\n                        <DisplayTerm>Comments and advice</DisplayTerm>\n                        <DescriptiveText>This is to see if writing back works</DescriptiveText>\n                    </Event>\n                </ConsultationElement>\n                <ConsultationElement>\n                    <RefID>3</RefID>\n                    <Header>\n                        <Term>Comment</Term>\n                    </Header>\n                    <Event>\n                        <RefID>1</RefID>\n                        <GUID>7e9aaa22-ee18-4bd7-9e5d-74e95746bf2b</GUID>\n                        <AssignedDate>19/05/2025 15:43:05</AssignedDate>\n                        <AuthorID>\n                            <RefID>5885</RefID>\n                        </AuthorID>\n                        <OriginalAuthor>\n                            <User>\n                                <RefID>5885</RefID>\n                            </User>\n                        </OriginalAuthor>\n                        <DisplayTerm>Important red flags to be aware of</DisplayTerm>\n                        <DescriptiveText>let me see the flags</DescriptiveText>\n                    </Event>\n                </ConsultationElement>\n                <ConsultationElement>\n                    <RefID>5</RefID>\n                    <Header>\n                        <Term>Comment</Term>\n                    </Header>\n                    <Event>\n                        <RefID>1</RefID>\n                        <GUID>9f3ba40e-c58f-4bac-aed4-e4eb317ee070</GUID>\n                        <AssignedDate>19/05/2025 15:43:05</AssignedDate>\n              ...
#   } ]
# }
# {
#   "resourceType": "Task",
#   "id": "17eb465f-3c31-48df-b6be-37600e15712c",
#   "meta": {
#     "versionId": "154",
#     "lastUpdated": "2025-06-26T11:45:44.251Z"
#   },
#   "identifier": [ {
#     "system": "https://fhir.virtually.healthcare/Id/Task",
#     "value": "8b6bba41-5085-4127-b785-9bc9b615a37e"
#   } ],
#   "status": "completed",
#   "intent": "order",
#   "priority": "routine",
#   "code": {
#     "coding": [ {
#       "system": "http://fhir.virtuallyhealthcare.co.uk/CodeSystem/tasks",
#       "code": "WRITEBACK",
#       "display": "Consultation Write Back"
#     } ]
#   },
#   "focus": {
#     "reference": "Encounter/ffc6c3d6-b00e-4954-8431-486188514529",
#     "identifier": {
#       "system": "https://fhir.virtually.healthcare/Id/Encounter",
#       "value": "f7ff9fd2-11f7-4a4e-9d84-dfccc669c7e9"
#     }
#   },
#   "for": {
#     "reference": "Patient/f3501365-9b30-4fb5-8729-ac4cdf56ce58"
#   },
#   "authoredOn": "2025-03-17T23:09:27+00:00",
#   "owner": {
#     "reference": "Organization/61a55cac-08d5-4cf8-a4d5-581f50962a82",
#     "identifier": {
#       "system": "https://fhir.nhs.uk/Id/ods-organization-code",
#       "value": "F83004"
#     }
#   },
#   "note": [ {
#     "time": "2025-03-17T23:10:36+00:00",
#     "text": "Technical error"
#   }, {
#     "time": "2025-03-17T23:11:28+00:00",
#     "text": "Moved from failure list accept list for retry"
#   }, {
#     "time": "2025-03-17T23:12:34+00:00",
#     "text": "Technical error"
#   }, {
#     "time": "2025-03-17T23:13:29+00:00",
#     "text": "Moved from failure list accept list for retry"
#   }, {
#     "time": "2025-03-17T23:14:34+00:00",
#     "text": "Technical error"
#   }, {
#     "time": "2025-03-17T23:15:28+00:00",
#     "text": "Moved from failure list accept list for retry"
#   }, {
#     "time": "2025-03-17T23:16:29+00:00",
#     "text": "Technical error"
#   }, {
#     "time": "2025-03-17T23:17:28+00:00",
#     "text": "Moved from failure list accept list for retry"
#   }, {
#     "time": "2025-03-17T23:18:29+00:00",
#     "text": "Technical error"
#   } ],
#   "input": [ {
#     "type": {
#       "text": "ResourceReference"
#     },
#     "valueReference": {
#       "reference": "QuestionnaireResponse/d635f644-ecaa-48d4-9e36-c562b50f0a71"
#     }
#   } ]
# }

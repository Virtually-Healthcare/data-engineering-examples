# %% [markdown]
# Thanks to this article https://medium.com/analytics-vidhya/primer-on-gps-data-with-strava-and-python-cd7c6c1d715a and https://towardsdatascience.com/parsing-fitness-tracker-data-with-python-a59e7dc17418/
#
# Uses this library https://pypi.org/project/gpxpy/

# %%
import gpxpy

path = 'Strava/L_Etape_2024.gpx'

with open(path, 'r') as f:
   gpx = gpxpy.parse(f)

print('Tracks ',len(gpx.tracks))
print(gpx.tracks[0].name)
print('Segments ', len(gpx.tracks[0].segments))
print('Segment Points ', len(gpx.tracks[0].segments[0].points))

data = gpx.tracks[0].segments[0].points

track = gpx.tracks[0]
segment = track.segments[0]
random_point = segment.points[11144]
point = random_point
last_point = segment.points[11143]
random_point
# Out:
# Tracks  1
# L’Etape 2024
# Segments  1
# Segment Points  34008
# GPXTrackPoint(43.903134, 7.413812, elevation=481.5, time=datetime.datetime(2024, 7, 6, 8, 55, 30, tzinfo=SimpleTZ('Z')))

# %%
import mpu

power = None
hr = None
cadence = None
temp = None
# Safely access extensions
for ext in point.extensions:
    if ext.tag.endswith('power'):
        power = ext.text
    if ext is not None:
        for child in ext:
            if (child.tag.endswith('hr')):
                hr = child.text
            if (child.tag.endswith('cad')):
                cadence = child.text
            if (child.tag.endswith('atemp')):
                temp = child.text
duration = point.time - last_point.time
dist = mpu.haversine_distance((point.latitude, point.longitude), (last_point.latitude, last_point.longitude))
print(dist)  # gives 278.45817507541943.
print(duration)
print(point.latitude)
print(power)
print(cadence)
print(hr)
# Out:
# 0.003921397552719817
# 0:00:01
# 43.903134
# 238
# 68
# 157

# %%
data
# Out:
# [GPXTrackPoint(43.66914, 7.213582, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 3, 53, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669136, 7.213558, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 3, 54, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669132, 7.213534, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 3, 55, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669129, 7.21349, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 3, 56, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669117, 7.213446, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 3, 57, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669101, 7.213398, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 3, 58, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669086, 7.213352, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 3, 59, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669071, 7.213313, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 4, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669033, 7.213266, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 4, 1, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669021, 7.213224, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 4, 2, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669011, 7.21319, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 4, 3, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668956, 7.213158, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 4, 4, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668914, 7.213134, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 4, 5, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668883, 7.213108, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 4, 6, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668846, 7.213086, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 4, 7, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668827, 7.213041, elevation=8.5, time=datetime.datetime(2024, 7, 6, 5, 4, 8, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668808, 7.212989, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 4, 9, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668779, 7.212935, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 4, 10, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66875, 7.212876, elevation=8.9, time=datetime.datetime(2024, 7, 6, 5, 4, 11, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668728, 7.212832, elevation=9.0, time=datetime.datetime(2024, 7, 6, 5, 4, 12, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668705, 7.21278, elevation=9.2, time=datetime.datetime(2024, 7, 6, 5, 4, 13, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668686, 7.212727, elevation=9.2, time=datetime.datetime(2024, 7, 6, 5, 4, 14, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668667, 7.212667, elevation=9.3, time=datetime.datetime(2024, 7, 6, 5, 4, 15, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66864, 7.212599, elevation=9.3, time=datetime.datetime(2024, 7, 6, 5, 4, 16, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668621, 7.212539, elevation=9.3, time=datetime.datetime(2024, 7, 6, 5, 4, 17, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66859, 7.212476, elevation=9.3, time=datetime.datetime(2024, 7, 6, 5, 4, 18, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66856, 7.212416, elevation=9.2, time=datetime.datetime(2024, 7, 6, 5, 4, 19, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668529, 7.212351, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 4, 20, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668499, 7.212284, elevation=8.9, time=datetime.datetime(2024, 7, 6, 5, 4, 21, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668484, 7.212256, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 4, 22, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668465, 7.212221, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 4, 23, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668442, 7.212185, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 4, 24, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668423, 7.212145, elevation=8.5, time=datetime.datetime(2024, 7, 6, 5, 4, 25, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668404, 7.21211, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 4, 26, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668385, 7.212072, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 4, 27, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668366, 7.212036, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 4, 28, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668346, 7.21201, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 4, 29, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668316, 7.21199, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 4, 30, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668277, 7.21198, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 4, 31, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668239, 7.211973, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 4, 32, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668201, 7.211967, elevation=7.8, time=datetime.datetime(2024, 7, 6, 5, 4, 33, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668156, 7.211963, elevation=7.7, time=datetime.datetime(2024, 7, 6, 5, 4, 34, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668118, 7.211965, elevation=7.7, time=datetime.datetime(2024, 7, 6, 5, 4, 35, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668083, 7.211965, elevation=7.6, time=datetime.datetime(2024, 7, 6, 5, 4, 36, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668047, 7.211965, elevation=7.6, time=datetime.datetime(2024, 7, 6, 5, 4, 37, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668008, 7.211966, elevation=7.6, time=datetime.datetime(2024, 7, 6, 5, 4, 38, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66798, 7.211963, elevation=7.6, time=datetime.datetime(2024, 7, 6, 5, 4, 39, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667961, 7.211958, elevation=7.6, time=datetime.datetime(2024, 7, 6, 5, 4, 40, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667946, 7.211952, elevation=7.5, time=datetime.datetime(2024, 7, 6, 5, 4, 41, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667924, 7.211942, elevation=7.5, time=datetime.datetime(2024, 7, 6, 5, 4, 42, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.6679, 7.211925, elevation=7.5, time=datetime.datetime(2024, 7, 6, 5, 4, 43, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667873, 7.2119, elevation=7.4, time=datetime.datetime(2024, 7, 6, 5, 4, 44, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667847, 7.211871, elevation=7.3, time=datetime.datetime(2024, 7, 6, 5, 4, 45, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667827, 7.211843, elevation=7.3, time=datetime.datetime(2024, 7, 6, 5, 4, 46, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667797, 7.211828, elevation=7.2, time=datetime.datetime(2024, 7, 6, 5, 4, 47, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667758, 7.21183, elevation=7.2, time=datetime.datetime(2024, 7, 6, 5, 4, 48, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667716, 7.211835, elevation=7.2, time=datetime.datetime(2024, 7, 6, 5, 4, 49, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667674, 7.211842, elevation=7.3, time=datetime.datetime(2024, 7, 6, 5, 4, 50, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667625, 7.211847, elevation=7.3, time=datetime.datetime(2024, 7, 6, 5, 4, 51, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667579, 7.211855, elevation=7.3, time=datetime.datetime(2024, 7, 6, 5, 4, 52, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667533, 7.211862, elevation=7.3, time=datetime.datetime(2024, 7, 6, 5, 4, 53, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667487, 7.211864, elevation=7.3, time=datetime.datetime(2024, 7, 6, 5, 4, 54, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667445, 7.211874, elevation=7.3, time=datetime.datetime(2024, 7, 6, 5, 4, 55, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667396, 7.211889, elevation=7.4, time=datetime.datetime(2024, 7, 6, 5, 4, 56, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667342, 7.211907, elevation=7.4, time=datetime.datetime(2024, 7, 6, 5, 4, 57, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667293, 7.211915, elevation=7.4, time=datetime.datetime(2024, 7, 6, 5, 4, 58, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667243, 7.211922, elevation=7.3, time=datetime.datetime(2024, 7, 6, 5, 4, 59, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667199, 7.211928, elevation=7.4, time=datetime.datetime(2024, 7, 6, 5, 5, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667154, 7.211941, elevation=7.4, time=datetime.datetime(2024, 7, 6, 5, 5, 1, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667083, 7.211871, elevation=7.2, time=datetime.datetime(2024, 7, 6, 5, 5, 2, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667027, 7.211857, elevation=7.2, time=datetime.datetime(2024, 7, 6, 5, 5, 3, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666973, 7.21184, elevation=7.2, time=datetime.datetime(2024, 7, 6, 5, 5, 4, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666923, 7.21183, elevation=7.1, time=datetime.datetime(2024, 7, 6, 5, 5, 5, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666865, 7.21182, elevation=7.1, time=datetime.datetime(2024, 7, 6, 5, 5, 6, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666811, 7.211813, elevation=7.0, time=datetime.datetime(2024, 7, 6, 5, 5, 7, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666762, 7.21181, elevation=7.0, time=datetime.datetime(2024, 7, 6, 5, 5, 8, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666709, 7.211807, elevation=7.0, time=datetime.datetime(2024, 7, 6, 5, 5, 9, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666663, 7.211803, elevation=7.0, time=datetime.datetime(2024, 7, 6, 5, 5, 10, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666621, 7.211805, elevation=7.0, time=datetime.datetime(2024, 7, 6, 5, 5, 11, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666572, 7.211812, elevation=7.0, time=datetime.datetime(2024, 7, 6, 5, 5, 12, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666531, 7.211818, elevation=7.0, time=datetime.datetime(2024, 7, 6, 5, 5, 13, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666489, 7.211827, elevation=7.0, time=datetime.datetime(2024, 7, 6, 5, 5, 14, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666442, 7.211827, elevation=7.0, time=datetime.datetime(2024, 7, 6, 5, 5, 15, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.6664, 7.211817, elevation=7.0, time=datetime.datetime(2024, 7, 6, 5, 5, 16, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666366, 7.211803, elevation=7.0, time=datetime.datetime(2024, 7, 6, 5, 5, 17, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66634, 7.211781, elevation=7.0, time=datetime.datetime(2024, 7, 6, 5, 5, 18, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666329, 7.211741, elevation=6.9, time=datetime.datetime(2024, 7, 6, 5, 5, 19, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666321, 7.211697, elevation=6.9, time=datetime.datetime(2024, 7, 6, 5, 5, 20, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666313, 7.211644, elevation=6.9, time=datetime.datetime(2024, 7, 6, 5, 5, 21, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666301, 7.211594, elevation=6.9, time=datetime.datetime(2024, 7, 6, 5, 5, 22, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66629, 7.211555, elevation=6.9, time=datetime.datetime(2024, 7, 6, 5, 5, 23, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666279, 7.211537, elevation=7.0, time=datetime.datetime(2024, 7, 6, 5, 5, 24, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666271, 7.211528, elevation=7.0, time=datetime.datetime(2024, 7, 6, 5, 5, 25, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666267, 7.211525, elevation=7.0, time=datetime.datetime(2024, 7, 6, 5, 5, 26, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666264, 7.211522, elevation=6.9, time=datetime.datetime(2024, 7, 6, 5, 5, 27, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666264, 7.211522, elevation=6.9, time=datetime.datetime(2024, 7, 6, 5, 5, 28, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666264, 7.211522, elevation=6.9, time=datetime.datetime(2024, 7, 6, 5, 5, 29, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666229, 7.211502, elevation=6.9, time=datetime.datetime(2024, 7, 6, 5, 5, 37, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66621, 7.2115, elevation=6.9, time=datetime.datetime(2024, 7, 6, 5, 5, 38, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666191, 7.211502, elevation=6.9, time=datetime.datetime(2024, 7, 6, 5, 5, 39, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666168, 7.211507, elevation=6.9, time=datetime.datetime(2024, 7, 6, 5, 5, 40, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666145, 7.211512, elevation=6.9, time=datetime.datetime(2024, 7, 6, 5, 5, 41, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666118, 7.211517, elevation=6.9, time=datetime.datetime(2024, 7, 6, 5, 5, 42, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666088, 7.211529, elevation=6.9, time=datetime.datetime(2024, 7, 6, 5, 5, 43, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666061, 7.211549, elevation=6.8, time=datetime.datetime(2024, 7, 6, 5, 5, 44, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666038, 7.211579, elevation=6.8, time=datetime.datetime(2024, 7, 6, 5, 5, 45, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66602, 7.211615, elevation=6.8, time=datetime.datetime(2024, 7, 6, 5, 5, 46, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666016, 7.211666, elevation=6.7, time=datetime.datetime(2024, 7, 6, 5, 5, 47, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66602, 7.211719, elevation=6.7, time=datetime.datetime(2024, 7, 6, 5, 5, 48, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666023, 7.211772, elevation=6.8, time=datetime.datetime(2024, 7, 6, 5, 5, 49, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66603, 7.211822, elevation=6.8, time=datetime.datetime(2024, 7, 6, 5, 5, 50, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666039, 7.211884, elevation=6.9, time=datetime.datetime(2024, 7, 6, 5, 5, 51, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666042, 7.211944, elevation=7.0, time=datetime.datetime(2024, 7, 6, 5, 5, 52, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66605, 7.212006, elevation=7.1, time=datetime.datetime(2024, 7, 6, 5, 5, 53, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666062, 7.212071, elevation=7.1, time=datetime.datetime(2024, 7, 6, 5, 5, 54, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666069, 7.212132, elevation=7.1, time=datetime.datetime(2024, 7, 6, 5, 5, 55, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666077, 7.212192, elevation=7.1, time=datetime.datetime(2024, 7, 6, 5, 5, 56, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666088, 7.212255, elevation=7.1, time=datetime.datetime(2024, 7, 6, 5, 5, 57, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666096, 7.212319, elevation=7.2, time=datetime.datetime(2024, 7, 6, 5, 5, 58, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666103, 7.212389, elevation=7.3, time=datetime.datetime(2024, 7, 6, 5, 5, 59, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666115, 7.212457, elevation=7.4, time=datetime.datetime(2024, 7, 6, 5, 6, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666123, 7.212524, elevation=7.5, time=datetime.datetime(2024, 7, 6, 5, 6, 1, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666138, 7.212585, elevation=7.6, time=datetime.datetime(2024, 7, 6, 5, 6, 2, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666153, 7.212654, elevation=7.7, time=datetime.datetime(2024, 7, 6, 5, 6, 3, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66616, 7.212726, elevation=7.7, time=datetime.datetime(2024, 7, 6, 5, 6, 4, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666172, 7.212809, elevation=7.8, time=datetime.datetime(2024, 7, 6, 5, 6, 5, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66618, 7.212889, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 6, 6, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666187, 7.212969, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 6, 7, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666195, 7.213051, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 6, 8, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666206, 7.213132, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 6, 9, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666214, 7.213214, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 6, 10, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666222, 7.213298, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 6, 11, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666233, 7.213384, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 6, 12, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666244, 7.213462, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 6, 13, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666256, 7.213551, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 6, 14, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666267, 7.213638, elevation=8.5, time=datetime.datetime(2024, 7, 6, 5, 6, 15, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666275, 7.21373, elevation=8.5, time=datetime.datetime(2024, 7, 6, 5, 6, 16, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666283, 7.21382, elevation=8.6, time=datetime.datetime(2024, 7, 6, 5, 6, 17, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666286, 7.213901, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 6, 18, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666294, 7.213994, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 6, 19, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666252, 7.214044, elevation=9.0, time=datetime.datetime(2024, 7, 6, 5, 6, 20, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666267, 7.214127, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 6, 21, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666282, 7.214214, elevation=9.3, time=datetime.datetime(2024, 7, 6, 5, 6, 22, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666301, 7.214304, elevation=9.5, time=datetime.datetime(2024, 7, 6, 5, 6, 23, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666313, 7.214398, elevation=9.7, time=datetime.datetime(2024, 7, 6, 5, 6, 24, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666321, 7.214488, elevation=9.9, time=datetime.datetime(2024, 7, 6, 5, 6, 25, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666332, 7.214576, elevation=9.7, time=datetime.datetime(2024, 7, 6, 5, 6, 26, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666343, 7.21466, elevation=9.5, time=datetime.datetime(2024, 7, 6, 5, 6, 27, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666355, 7.214757, elevation=9.3, time=datetime.datetime(2024, 7, 6, 5, 6, 28, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666367, 7.21485, elevation=9.0, time=datetime.datetime(2024, 7, 6, 5, 6, 29, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666378, 7.214942, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 6, 30, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666398, 7.215044, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 6, 31, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666488, 7.215075, elevation=8.6, time=datetime.datetime(2024, 7, 6, 5, 6, 32, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666523, 7.215158, elevation=8.6, time=datetime.datetime(2024, 7, 6, 5, 6, 33, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666546, 7.215233, elevation=8.6, time=datetime.datetime(2024, 7, 6, 5, 6, 34, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666561, 7.215295, elevation=8.6, time=datetime.datetime(2024, 7, 6, 5, 6, 35, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666573, 7.215335, elevation=8.5, time=datetime.datetime(2024, 7, 6, 5, 6, 36, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666584, 7.215358, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 6, 37, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666588, 7.215375, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 6, 38, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666584, 7.215388, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 6, 39, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66658, 7.215402, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 6, 40, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666573, 7.215429, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 6, 41, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666588, 7.215458, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 6, 42, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666603, 7.215506, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 6, 43, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666622, 7.215563, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 6, 44, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666641, 7.215628, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 6, 45, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666656, 7.21569, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 6, 46, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666672, 7.215762, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 6, 47, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666683, 7.215835, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 6, 48, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666699, 7.21591, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 6, 49, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66671, 7.215986, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 6, 50, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666725, 7.216068, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 6, 51, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666733, 7.21615, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 6, 52, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666744, 7.216233, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 6, 53, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666756, 7.216316, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 6, 54, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666771, 7.216399, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 6, 55, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666786, 7.216483, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 6, 56, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666801, 7.216567, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 6, 57, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666817, 7.216653, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 6, 58, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666832, 7.216738, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 6, 59, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666848, 7.216835, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666862, 7.21692, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 1, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666877, 7.217012, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 2, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666893, 7.217106, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 3, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666908, 7.217192, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 4, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666924, 7.217285, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 5, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666935, 7.217375, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 6, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666954, 7.217463, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 7, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666973, 7.217553, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 7, 8, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.666991, 7.217635, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 7, 9, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667015, 7.217727, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 10, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667038, 7.217814, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 11, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66706, 7.217899, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 12, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667084, 7.21799, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 13, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667111, 7.218075, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 14, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667134, 7.218159, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 15, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66716, 7.218244, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 16, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667183, 7.218327, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 17, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66721, 7.218411, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 18, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66724, 7.218493, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 19, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667266, 7.218574, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 20, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667297, 7.218657, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 21, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667328, 7.218744, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 22, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667355, 7.218828, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 23, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667385, 7.218908, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 7, 24, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66742, 7.218993, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 7, 25, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66745, 7.219076, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 7, 26, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667485, 7.219158, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 7, 27, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667519, 7.219239, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 7, 28, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667555, 7.219315, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 7, 29, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667587, 7.219395, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 7, 30, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667626, 7.219476, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 7, 31, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667663, 7.219553, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 7, 32, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667702, 7.219632, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 7, 33, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66774, 7.21971, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 34, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667782, 7.219793, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 35, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66782, 7.219871, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 7, 36, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667862, 7.219949, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 7, 37, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667904, 7.220025, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 7, 38, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667947, 7.220103, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 7, 39, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.667988, 7.220176, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 7, 40, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668026, 7.220251, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 7, 41, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668068, 7.220326, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 7, 42, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668109, 7.220398, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 7, 43, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668154, 7.22047, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 7, 44, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668202, 7.220544, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 7, 45, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668247, 7.220615, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 7, 46, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668297, 7.220684, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 7, 47, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668338, 7.220745, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 7, 48, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668389, 7.220821, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 49, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668438, 7.220888, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 50, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668488, 7.220955, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 51, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668534, 7.221022, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 7, 52, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668587, 7.221091, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 7, 53, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668633, 7.221154, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 7, 54, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668682, 7.221217, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 7, 55, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668728, 7.22128, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 7, 56, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668778, 7.221344, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 7, 57, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668827, 7.22141, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 58, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668875, 7.221476, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 7, 59, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668926, 7.221547, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.668975, 7.221614, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, 1, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669026, 7.22168, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 8, 2, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669075, 7.221745, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 8, 3, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669125, 7.221811, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 8, 4, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669178, 7.221877, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 8, 5, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669228, 7.221948, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, 6, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669281, 7.222018, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, 7, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669331, 7.22209, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, 8, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66938, 7.22216, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 8, 9, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669429, 7.222229, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 8, 10, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669475, 7.222301, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 8, 11, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669529, 7.222371, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 8, 12, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669578, 7.222438, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 8, 13, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669621, 7.2225, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 8, 14, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669678, 7.222579, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 8, 15, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669728, 7.222645, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 8, 16, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669777, 7.222716, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 8, 17, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669823, 7.222788, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 8, 18, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669871, 7.222855, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 8, 19, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.669926, 7.222923, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, 20, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.66998, 7.222991, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, 21, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.670025, 7.223061, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, 22, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.670079, 7.223129, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, 23, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.670127, 7.223198, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, 24, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.670182, 7.223267, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, 25, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.670232, 7.223336, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, 26, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.670281, 7.223406, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, 27, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.670333, 7.223474, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, 28, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.67038, 7.223543, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, 29, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.670434, 7.223611, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, 30, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.670483, 7.22368, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, 31, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.670535, 7.223747, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, 32, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.67058, 7.22381, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, 33, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.670635, 7.223888, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, 34, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.670685, 7.223956, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 8, 35, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.670731, 7.224024, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 8, 36, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.670777, 7.224095, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 8, 37, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.670822, 7.22416, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 8, 38, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.670872, 7.224223, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 8, 39, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.670917, 7.224286, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 8, 40, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.670964, 7.224353, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 8, 41, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671014, 7.224413, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 8, 42, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.67106, 7.224475, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 8, 43, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671109, 7.224535, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 8, 44, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671154, 7.224595, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 8, 45, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.6712, 7.224653, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 8, 46, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671242, 7.224713, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 8, 47, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671281, 7.224771, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 8, 48, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671322, 7.224828, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 8, 49, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.67136, 7.224886, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 8, 50, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671399, 7.224946, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 8, 51, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671436, 7.225004, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 8, 52, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671471, 7.225062, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 8, 53, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671504, 7.225112, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 8, 54, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671532, 7.225166, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 8, 55, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671559, 7.225221, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 8, 56, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671581, 7.225272, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 8, 57, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671616, 7.225327, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 8, 58, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.67165, 7.225384, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 8, 59, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671685, 7.225447, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 9, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671723, 7.225502, elevation=8.4, time=datetime.datetime(2024, 7, 6, 5, 9, 1, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671769, 7.225559, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 9, 2, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671821, 7.225615, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 9, 3, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671883, 7.22567, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 9, 4, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671933, 7.225726, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 9, 5, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.671992, 7.225773, elevation=8.3, time=datetime.datetime(2024, 7, 6, 5, 9, 6, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.672055, 7.225822, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 7, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.672104, 7.225871, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 8, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.672152, 7.22592, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 9, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.672206, 7.225969, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 10, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.672255, 7.226017, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 11, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.672314, 7.226064, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 12, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.672368, 7.226112, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 13, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.672415, 7.226156, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 14, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.672471, 7.226202, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 15, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.672524, 7.226245, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 16, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.672578, 7.226291, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 17, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.672624, 7.226336, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 18, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.672676, 7.226382, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 19, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.672726, 7.226427, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 20, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.672776, 7.22647, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 21, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.672825, 7.226515, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 22, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.672883, 7.226557, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 23, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.672928, 7.226602, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 24, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.672982, 7.226644, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 25, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.673035, 7.226687, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 26, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.673089, 7.226727, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 27, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.673138, 7.226767, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 28, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.673192, 7.226806, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 29, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.673241, 7.226844, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 30, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.673286, 7.226881, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 31, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.673337, 7.226919, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 32, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.673386, 7.226957, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 33, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.673435, 7.226997, elevation=8.2, time=datetime.datetime(2024, 7, 6, 5, 9, 34, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.673485, 7.227033, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 9, 35, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.673539, 7.227067, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 9, 36, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.673588, 7.2271, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 9, 37, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.673645, 7.227135, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 9, 38, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.673702, 7.227173, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 9, 39, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.673764, 7.227208, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 9, 40, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.673829, 7.227242, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 9, 41, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.67389, 7.227277, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 9, 42, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.673963, 7.227309, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 9, 43, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.674026, 7.22734, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 9, 44, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.674092, 7.227372, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 9, 45, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.674152, 7.227403, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 9, 46, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.674214, 7.227435, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 9, 47, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.674275, 7.227469, elevation=8.1, time=datetime.datetime(2024, 7, 6, 5, 9, 48, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.674336, 7.227502, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 9, 49, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.674393, 7.227537, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 9, 50, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.674451, 7.227567, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 9, 51, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.674531, 7.227594, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 9, 52, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.674596, 7.227622, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 9, 53, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.674648, 7.227651, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 9, 54, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.674703, 7.227685, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 9, 55, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.674764, 7.227713, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 9, 56, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.674825, 7.22774, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 9, 57, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.674882, 7.227772, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 9, 58, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.674936, 7.227801, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 9, 59, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.674992, 7.227834, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.675044, 7.227866, elevation=8.0, time=datetime.datetime(2024, 7, 6, 5, 10, 1, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.675099, 7.227904, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 2, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.675156, 7.227937, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 3, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.675202, 7.227962, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 4, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.675271, 7.228001, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 5, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.675324, 7.228032, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 6, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.675381, 7.228059, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 7, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.675428, 7.228083, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 8, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.675492, 7.228119, elevation=7.8, time=datetime.datetime(2024, 7, 6, 5, 10, 9, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.675548, 7.22815, elevation=7.8, time=datetime.datetime(2024, 7, 6, 5, 10, 10, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.675607, 7.228179, elevation=7.8, time=datetime.datetime(2024, 7, 6, 5, 10, 11, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.675667, 7.228209, elevation=7.8, time=datetime.datetime(2024, 7, 6, 5, 10, 12, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.675721, 7.22824, elevation=7.8, time=datetime.datetime(2024, 7, 6, 5, 10, 13, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.675781, 7.22827, elevation=7.8, time=datetime.datetime(2024, 7, 6, 5, 10, 14, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.675837, 7.228296, elevation=7.8, time=datetime.datetime(2024, 7, 6, 5, 10, 15, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.675896, 7.22832, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 16, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.675958, 7.228345, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 17, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.676019, 7.228371, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 18, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.676079, 7.228404, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 19, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.67614, 7.228439, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 20, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.676197, 7.228472, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 21, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.676262, 7.228505, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 22, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.676322, 7.228539, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 23, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.676381, 7.228576, elevation=7.8, time=datetime.datetime(2024, 7, 6, 5, 10, 24, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.676442, 7.228611, elevation=7.8, time=datetime.datetime(2024, 7, 6, 5, 10, 25, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.676503, 7.228644, elevation=7.8, time=datetime.datetime(2024, 7, 6, 5, 10, 26, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.676564, 7.228678, elevation=7.8, time=datetime.datetime(2024, 7, 6, 5, 10, 27, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.676625, 7.228709, elevation=7.8, time=datetime.datetime(2024, 7, 6, 5, 10, 28, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.676686, 7.228742, elevation=7.8, time=datetime.datetime(2024, 7, 6, 5, 10, 29, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.676747, 7.228772, elevation=7.8, time=datetime.datetime(2024, 7, 6, 5, 10, 30, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.6768, 7.228803, elevation=7.8, time=datetime.datetime(2024, 7, 6, 5, 10, 31, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.676857, 7.228834, elevation=7.8, time=datetime.datetime(2024, 7, 6, 5, 10, 32, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.676911, 7.228867, elevation=7.8, time=datetime.datetime(2024, 7, 6, 5, 10, 33, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.676965, 7.228907, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 34, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.677014, 7.228949, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 35, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.677064, 7.228989, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 36, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.677109, 7.22902, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 37, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.677162, 7.229048, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 38, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.677215, 7.229076, elevation=7.9, time=datetime.datetime(2024, 7, 6, 5, 10, 39, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.677269, 7.229105, elevation=7.8, time=datetime.datetime(2024, 7, 6, 5, 10, 40, tzinfo=SimpleTZ('Z'))),
# ...
#  GPXTrackPoint(43.692986, 7.253387, elevation=8.6, time=datetime.datetime(2024, 7, 6, 5, 18, 32, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.692986, 7.253412, elevation=8.6, time=datetime.datetime(2024, 7, 6, 5, 18, 33, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.692989, 7.25345, elevation=8.6, time=datetime.datetime(2024, 7, 6, 5, 18, 34, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.692996, 7.253488, elevation=8.6, time=datetime.datetime(2024, 7, 6, 5, 18, 35, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693008, 7.253538, elevation=8.6, time=datetime.datetime(2024, 7, 6, 5, 18, 36, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.69302, 7.25359, elevation=8.6, time=datetime.datetime(2024, 7, 6, 5, 18, 37, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693035, 7.253637, elevation=8.6, time=datetime.datetime(2024, 7, 6, 5, 18, 38, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693043, 7.253678, elevation=8.6, time=datetime.datetime(2024, 7, 6, 5, 18, 39, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693054, 7.253715, elevation=8.6, time=datetime.datetime(2024, 7, 6, 5, 18, 40, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693062, 7.253747, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 18, 41, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693069, 7.253777, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 18, 42, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693073, 7.253808, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 18, 43, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693081, 7.25384, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 18, 44, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693088, 7.253874, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 18, 45, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.6931, 7.253911, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 18, 46, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693112, 7.253947, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 18, 47, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693119, 7.253983, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 18, 48, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693127, 7.25402, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 18, 49, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693138, 7.254053, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 18, 50, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693142, 7.254088, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 18, 51, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693153, 7.254125, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 18, 52, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693161, 7.254163, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 18, 53, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693169, 7.254203, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 18, 54, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.69318, 7.254246, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 18, 55, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693188, 7.254287, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 18, 56, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693199, 7.254325, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 18, 57, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693207, 7.254363, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 18, 58, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693218, 7.254399, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 18, 59, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693229, 7.254441, elevation=8.7, time=datetime.datetime(2024, 7, 6, 5, 19, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693237, 7.254484, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 19, 1, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693249, 7.254529, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 19, 2, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.69326, 7.254575, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 19, 3, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693268, 7.25462, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 19, 4, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693286, 7.254667, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 19, 5, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693298, 7.254714, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 19, 6, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693314, 7.254762, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 19, 7, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693321, 7.254815, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 19, 8, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693329, 7.254868, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 19, 9, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.69334, 7.25492, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 19, 10, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693348, 7.254975, elevation=8.9, time=datetime.datetime(2024, 7, 6, 5, 19, 11, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693359, 7.255034, elevation=8.9, time=datetime.datetime(2024, 7, 6, 5, 19, 12, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693375, 7.255091, elevation=8.9, time=datetime.datetime(2024, 7, 6, 5, 19, 13, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693386, 7.255151, elevation=8.9, time=datetime.datetime(2024, 7, 6, 5, 19, 14, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693397, 7.255207, elevation=8.9, time=datetime.datetime(2024, 7, 6, 5, 19, 15, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693413, 7.255267, elevation=8.9, time=datetime.datetime(2024, 7, 6, 5, 19, 16, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693428, 7.255328, elevation=8.9, time=datetime.datetime(2024, 7, 6, 5, 19, 17, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693443, 7.25539, elevation=9.0, time=datetime.datetime(2024, 7, 6, 5, 19, 18, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693455, 7.255451, elevation=9.0, time=datetime.datetime(2024, 7, 6, 5, 19, 19, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.69347, 7.255512, elevation=9.0, time=datetime.datetime(2024, 7, 6, 5, 19, 20, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693481, 7.255573, elevation=9.0, time=datetime.datetime(2024, 7, 6, 5, 19, 21, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693493, 7.255637, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 22, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693508, 7.2557, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 23, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.69352, 7.255762, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 24, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693535, 7.255821, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 25, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693546, 7.255879, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 26, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693557, 7.255927, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 27, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693565, 7.255977, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 28, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693573, 7.256021, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 29, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.69358, 7.256058, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 30, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693588, 7.2561, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 31, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693596, 7.25614, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 32, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693607, 7.256175, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 33, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693615, 7.256213, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 34, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693626, 7.256253, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 35, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693638, 7.2563, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 36, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693649, 7.256349, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 37, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.69366, 7.256397, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 38, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693668, 7.256443, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 39, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693679, 7.256484, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 40, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693687, 7.256526, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 41, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693695, 7.256568, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 42, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693707, 7.256613, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 43, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693714, 7.256659, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 44, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693725, 7.256703, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 45, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693737, 7.25675, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 46, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693748, 7.256796, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 47, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.69376, 7.256845, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 48, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693775, 7.256897, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 49, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693786, 7.256949, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 50, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693798, 7.257003, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 51, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693813, 7.257061, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 52, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693829, 7.257125, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 53, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693844, 7.257191, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 54, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693855, 7.25726, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 55, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693871, 7.25733, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 56, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693886, 7.257397, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 57, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693897, 7.25746, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 58, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693909, 7.257515, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 19, 59, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.69392, 7.257566, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 20, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693932, 7.257613, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 20, 1, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693939, 7.257658, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 20, 2, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693951, 7.257702, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 20, 3, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693958, 7.257747, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 20, 4, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693974, 7.25779, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 20, 5, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693981, 7.257839, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 20, 6, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.693993, 7.257887, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 20, 7, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694008, 7.257942, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 20, 8, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694019, 7.257995, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 20, 9, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694035, 7.258055, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 20, 10, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694049, 7.25811, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 20, 11, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694068, 7.258174, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 20, 12, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694087, 7.258236, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 20, 13, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694099, 7.258303, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 20, 14, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694111, 7.258373, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 20, 15, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694126, 7.258437, elevation=9.1, time=datetime.datetime(2024, 7, 6, 5, 20, 16, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694137, 7.258499, elevation=9.0, time=datetime.datetime(2024, 7, 6, 5, 20, 17, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694145, 7.258562, elevation=9.0, time=datetime.datetime(2024, 7, 6, 5, 20, 18, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694157, 7.258615, elevation=9.0, time=datetime.datetime(2024, 7, 6, 5, 20, 19, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694164, 7.258663, elevation=9.0, time=datetime.datetime(2024, 7, 6, 5, 20, 20, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694171, 7.258702, elevation=9.0, time=datetime.datetime(2024, 7, 6, 5, 20, 21, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.69418, 7.258748, elevation=9.0, time=datetime.datetime(2024, 7, 6, 5, 20, 22, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694187, 7.258787, elevation=9.0, time=datetime.datetime(2024, 7, 6, 5, 20, 23, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694195, 7.258824, elevation=9.0, time=datetime.datetime(2024, 7, 6, 5, 20, 24, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694195, 7.258848, elevation=8.9, time=datetime.datetime(2024, 7, 6, 5, 20, 25, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694202, 7.25887, elevation=8.9, time=datetime.datetime(2024, 7, 6, 5, 20, 26, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694206, 7.258895, elevation=8.9, time=datetime.datetime(2024, 7, 6, 5, 20, 27, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694214, 7.258923, elevation=8.9, time=datetime.datetime(2024, 7, 6, 5, 20, 28, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694222, 7.258958, elevation=8.9, time=datetime.datetime(2024, 7, 6, 5, 20, 29, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694229, 7.258993, elevation=8.9, time=datetime.datetime(2024, 7, 6, 5, 20, 30, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694239, 7.259046, elevation=8.9, time=datetime.datetime(2024, 7, 6, 5, 20, 31, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.69424, 7.259062, elevation=8.9, time=datetime.datetime(2024, 7, 6, 5, 20, 32, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694248, 7.259101, elevation=8.9, time=datetime.datetime(2024, 7, 6, 5, 20, 33, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694248, 7.259139, elevation=8.9, time=datetime.datetime(2024, 7, 6, 5, 20, 34, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694256, 7.259177, elevation=8.9, time=datetime.datetime(2024, 7, 6, 5, 20, 35, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.69426, 7.259222, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 20, 36, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694263, 7.259267, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 20, 37, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694267, 7.259315, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 20, 38, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694275, 7.259376, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 20, 39, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694279, 7.259436, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 20, 40, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694283, 7.259498, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 20, 41, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.69429, 7.259556, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 20, 42, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(43.694297, 7.259616, elevation=8.8, time=datetime.datetime(2024, 7, 6, 5, 20, 43, tzinfo=SimpleTZ('Z'))),
#  ...]

# %%
import pandas as pd

df = pd.DataFrame(columns=['lat', 'lon', 'ele','time','power', 'hr', 'cad',
#                           'dist','duration'
                           ])
last_point = None
for point in data:
    power = None
    hr = None
    cadence = None
    temp = None
#    dist = None
#    duration = None
    # Safely access extensions
    for ext in point.extensions:
        if ext.tag.endswith('power'):
            power = int(ext.text)
        if ext is not None:
            for child in ext:
                if (child.tag.endswith('hr')):
                    hr = int(child.text)
                if (child.tag.endswith('cad')):
                    cadence = int(child.text)
                if (child.tag.endswith('atemp')):
                    temp = float(child.text)
#    if (last_point is not None):
#        duration = point.time - last_point.time
#        dist = mpu.haversine_distance((point.latitude, point.longitude), (last_point.latitude, last_point.longitude))
    new_row = pd.DataFrame({'lat': [point.latitude],
                            'lon': [point.longitude],
                            'ele': [point.elevation],
                            'time': [point.time],
                            'power': [power]
                            ,'hr': [hr],
                            'cad': [cadence]
#                            ,'duration': [duration]
#                            ,'dist': [dist]
                            })
    df = pd.concat([df, new_row], ignore_index=True)
# Out:
# /var/folders/16/bplm70c55mj7020_2tms62sh0000gn/T/ipykernel_7097/3762194169.py:39: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_row], ignore_index=True)

# %%
df['hr'] = df['hr'].astype(int)
df['cad'] = df['cad'].astype(int)
df['power'] = df['power'].astype(float)

# %%
df
# Out:
#              lat       lon     ele                      time  power   hr  cad
# 0      43.669140  7.213582     8.0 2024-07-06 05:03:53+00:00   18.0  124   53
# 1      43.669136  7.213558     8.0 2024-07-06 05:03:54+00:00   33.0  124   54
# 2      43.669132  7.213534     8.0 2024-07-06 05:03:55+00:00  108.0  124   56
# 3      43.669129  7.213490     8.0 2024-07-06 05:03:56+00:00   98.0  125   57
# 4      43.669117  7.213446     8.0 2024-07-06 05:03:57+00:00   76.0  125   56
# ...          ...       ...     ...                       ...    ...  ...  ...
# 34003  44.100117  7.023063  1673.3 2024-07-06 16:11:26+00:00    0.0  160    0
# 34004  44.100124  7.023058  1673.3 2024-07-06 16:11:27+00:00    0.0  160    0
# 34005  44.100128  7.023053  1673.4 2024-07-06 16:11:28+00:00    0.0  160    0
# 34006  44.100124  7.023050  1673.4 2024-07-06 16:11:29+00:00    0.0  160    0
# 34007  44.100128  7.023050  1673.5 2024-07-06 16:11:30+00:00    0.0  159    0
#
# [34008 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
plt.plot(df.lon, df.lat, 'o', markersize=1)

# %%
import gmplot

min_lat,max_lat = min(df.lat),max(df.lat)
min_lon,max_lon = min(df.lon),max(df.lon)

mymap = gmplot.GoogleMapPlotter(min_lat + (max_lat-min_lat)/2,min_lon + (max_lon-min_lon)/2, zoom=13, apikey='AIzaSyAOVYRIgupAurZup5y1PRh8Ismb1A3lLao')
mymap.plot(df['lat'],df['lon'],color='red',alpha=1,edge_width=3, precision = 6)

# %%
mymap.draw("LeEtape.html")

# %%
df.dtypes
# Out:
# lat                            float64
# lon                            float64
# ele                            float64
# time     datetime64[ns, SimpleTZ('Z')]
# power                          float64
# hr                               int64
# cad                              int64
# dtype: object

# %% [markdown]
# time column with time zone causes issues with plotting functions.
# Turn the time column into an index

# %%
df['time'] = df['time'].dt.tz_localize(None)
df = df.set_index('time')
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/16/bplm70c55mj7020_2tms62sh0000gn/T/ipykernel_7097/1133633397.py in ?()
# ----> 1 df = df.set_index('time')
#       2 df.head()
#
# ~/github/Phython/Play/.venv/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['time'] are in the columns"

# %%
close_px = df[['power','hr','cad']]
close_px.plot(kind='line',
              figsize=(10, 6),
              title='Power, Cadence and Heart Rate Over Time',
              grid=True,
              legend=True)
plt.xlabel('Time')
plt.show()

# %%
close_px.rolling('600s').mean().plot(kind='line',
              figsize=(10, 6),
              title='Power, Cadence and Heart Rate Over Time',
              grid=True,
              legend=True)
plt.xlabel('Time')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

rolling_mean = close_px.rolling('600s').mean()

plt.figure(figsize=(10, 4))
plt.plot(rolling_mean.index, rolling_mean)
plt.xlabel('Time')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
plt.gca().legend(['Power (W)', 'Heart Rate', 'Cadence'])
plt.title('Power, Cadence and Heart Rate Over Time')
plt.grid(True)
plt.show()

elevation = df[['ele']]
plt.figure(figsize=(10, 2))
plt.plot(elevation.index, elevation)
plt.xlabel('Time')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
plt.gca().legend(['Elevation (m)'])
plt.title('Elevation Over Time')
plt.grid(True)
plt.show()

# %% [markdown]
# Calculate values for [Physical Activity - Activity-based Measures](https://build.fhir.org/ig/HL7/physical-activity/measures.html#activity-based-measures)
#
# Convert to FHIR Bundle (type = collection)
